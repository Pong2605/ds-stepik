# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cu128
# !pip install numpy==1.26.4

# %%
import torch
print('Версия PyTorch:', torch.__version__)
print('CUDA доступна:', torch.cuda.is_available())
print('Имя GPU:', torch.cuda.get_device_name(0))
# Out:
# Версия PyTorch: 2.12.0.dev20260408+cu128
# CUDA доступна: True
# Имя GPU: NVIDIA GeForce RTX 5070 Ti

# %%
# #  Вариант 1: Стабильная версия (PyTorch 2.7.1) — Рекомендуется
# # Этот вариант наиболее надёжен и хорошо подходит для ваших задач RAG:

# # bash
# # Удалите старую версию
# !pip uninstall torch torchvision torchaudio -y

# # Установите PyTorch 2.7.1 с CUDA 12.8
# !pip install torch==2.7.1 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128

# %%
print('Версия PyTorch:', torch.__version__)
print('CUDA доступна:', torch.cuda.is_available())
print('Имя GPU:', torch.cuda.get_device_name(0))

# %%
# # Вариант 2: Максимальная производительность (PyTorch 2.10 с CUDA 13.0)
# # Для тех, кто хочет выжать максимум из RTX 5070 Ti:

# # bash
# # Установка PyTorch 2.10 с CUDA 13.0
# !pip install -U --no-cache-dir "torch" "torchvision" "torchaudio" --index-url "https://download.pytorch.org/whl/cu130"

# %%
print('Версия PyTorch:', torch.__version__)
print('CUDA доступна:', torch.cuda.is_available())
print('Имя GPU:', torch.cuda.get_device_name(0))

# %%
# # Дополнительные ускорители (опционально):

# # bash
# # xFormers для оптимизации внимания
# !pip install -U --no-deps "https://huggingface.co/Wildminder/AI-windows-whl/resolve/main/xformers-0.0.34%2Bd20260123.cu130torch2.10-cp39-abi3-win_amd64.whl"

# # Flash Attention 2
# pip install -U --no-deps "https://huggingface.co/Wildminder/AI-windows-whl/resolve/main/flash_attn-2.8.3%2Bd20260121.cu130torch2.10.0cxx11abiTRUE-cp312-cp312-win_amd64.whl"

# # Triton для Windows
# !pip install -U --no-deps "triton-windows"
