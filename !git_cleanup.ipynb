# %%
# !pip install git-filter-repo
# Out:
# Aborting: Refusing to destructively overwrite repo history since
# this does not look like a fresh clone.
#   (expected freshly packed repo)
# Please operate on a fresh clone instead.  If you want to proceed
# anyway, use --force.

# %%
# Удалить файлы больше 95 МБ из всей истории
# !git filter-repo --strip-blobs-bigger-than 95M

# %%
# Удалить файлы больше 50 МБ из всей истории
# !git filter-repo --strip-blobs-bigger-than 50M --force
# Out:
# Processed 664 blob sizes
# Processed 2650 blob sizes
# Processed 6412 blob sizes
# Processed 12384 blob sizes
# Processed 20267 blob sizes
# Processed 29844 blob sizes
# Processed 40679 blob sizes
# Processed 53865 blob sizes
# Processed 92597 blob sizes
# Processed 166304 blob sizes
# Processed 172190 blob sizes
#
# Parsed 1 commits
# Parsed 157 commits
# Parsed 175 commits
# Parsed 449 commits
# New history written in 38.96 seconds; now repacking/cleaning...
# Repacking your repo and cleaning out old unneeded objects
# HEAD is now at f49223dae updated
# Completely finished after 46.52 seconds.
