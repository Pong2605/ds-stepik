# %%
import numpy as np
import pandas as pd
import seaborn as sns

from catboost import CatBoostClassifier
from matplotlib import pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from pprint import pprint
from warnings import filterwarnings

filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # EDA

# %%
INPUT_DIR = "../input/advanced-dls-spring-2021/"
OUTPUT_DIR = "./"
data = pd.read_csv(INPUT_DIR + "train.csv")
external_data = pd.read_csv("../input/dfghdfgdfh/churn.csv")
X_test = pd.read_csv(INPUT_DIR + "test.csv")

# %%
data = pd.concat([data, external_data])

# %%
# data = data.drop_duplicates()

# %%
num_cols = [
    "ClientPeriod",
    "MonthlySpending",
    "TotalSpent",
]

cat_cols = [
    "Sex",
    "IsSeniorCitizen",
    "HasPartner",
    "HasChild",
    "HasPhoneService",
    "HasMultiplePhoneNumbers",
    "HasInternetService",
    "HasOnlineSecurityService",
    "HasOnlineBackup",
    "HasDeviceProtection",
    "HasTechSupportAccess",
    "HasOnlineTV",
    "HasMovieSubscription",
    "HasContractPhone",
    "IsBillingPaperless",
    "PaymentMethod",
]

target = 'Churn'

# %%
data[data.drop(target, axis=1).duplicated(keep=False)].sort_values(by=[*data.columns])
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 2543             0            19.70               Male                0
# 5218             0            19.70               Male                0
# 3697             0            20.00             Female                0
# 4380             0            20.00             Female                0
# 4326             0            25.35               Male                0
# ...            ...              ...        ...     ...              ...
# 4610            72           117.80     8684.8    Male                0
# 2162            72           118.20    8547.15    Male                0
# 6118            72           118.20    8547.15    Male                0
# 684             72           118.75    8672.45  Female                0
# 4586            72           118.75    8672.45  Female                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 2543        Yes      Yes             Yes                      No
# 5218        Yes      Yes             Yes                      No
# 3697        Yes      Yes             Yes                      No
# 4380        Yes      Yes             Yes                      No
# 4326        Yes      Yes             Yes                     Yes
# ...         ...      ...             ...                     ...
# 4610        Yes       No             Yes                     Yes
# 2162         No       No             Yes                     Yes
# 6118         No       No             Yes                     Yes
# 684         Yes      Yes             Yes                     Yes
# 4586        Yes      Yes             Yes                     Yes
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 2543                 No      No internet service  No internet service
# 5218                 No      No internet service  No internet service
# 3697                 No      No internet service  No internet service
# 4380                 No      No internet service  No internet service
# 4326                 No      No internet service  No internet service
# ...                 ...                      ...                  ...
# 4610        Fiber optic                      Yes                  Yes
# 2162        Fiber optic                      Yes                  Yes
# 6118        Fiber optic                      Yes                  Yes
# 684         Fiber optic                      Yes                  Yes
# 4586        Fiber optic                      Yes                  Yes
#
#       HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 2543  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 3697  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 4326  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 4610                  Yes                  Yes                  Yes
# 2162                  Yes                  Yes                  Yes
# 6118                  Yes                  Yes                  Yes
# 684                   Yes                  Yes                  Yes
# 4586                  Yes                  Yes                  Yes
#
#      HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 2543  No internet service         One year                Yes
# 5218  No internet service         One year                Yes
# 3697  No internet service         Two year                 No
# 4380  No internet service         Two year                 No
# 4326  No internet service         Two year                 No
# ...                   ...              ...                ...
# 4610                  Yes         One year                Yes
# 2162                  Yes         Two year                Yes
# 6118                  Yes         Two year                Yes
# 684                   Yes         Two year                Yes
# 4586                  Yes         Two year                Yes
#
#                   PaymentMethod  Churn
# 2543               Mailed check      0
# 5218               Mailed check      0
# 3697               Mailed check      0
# 4380               Mailed check      0
# 4326               Mailed check      0
# ...                         ...    ...
# 4610  Bank transfer (automatic)      1
# 2162           Electronic check      0
# 6118           Electronic check      0
# 684   Bank transfer (automatic)      0
# 4586  Bank transfer (automatic)      0
#
# [10584 rows x 20 columns]

# %%
data.replace(" ", np.nan, inplace=True)
X_test.replace(" ", np.nan, inplace=True)
pd.DataFrame(data.isna().sum(), columns=["NaN Count"]) \
    .sort_values("NaN Count") \
    .plot(kind="barh", legend=False, figsize=(12, 8));

# %% [markdown]
# We have 9 NaN's in TotalSpent column. Let's take a closer look at these clients.

# %%
data.sort_values("TotalSpent").tail(10)
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 753              0            20.25        NaN    Male                0
# 936              0            80.85        NaN  Female                0
# 1082             0            25.75        NaN    Male                0
# 1340             0            56.05        NaN  Female                0
# 3331             0            19.85        NaN    Male                0
# 3826             0            25.35        NaN    Male                0
# 4380             0            20.00        NaN  Female                0
# 5218             0            19.70        NaN    Male                0
# 6670             0            73.35        NaN  Female                0
# 6754             0            61.90        NaN    Male                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 753          No      Yes             Yes                      No
# 936         Yes      Yes             Yes                      No
# 1082        Yes      Yes             Yes                     Yes
# 1340        Yes      Yes              No        No phone service
# 3331        Yes      Yes             Yes                      No
# 3826        Yes      Yes             Yes                     Yes
# 4380        Yes      Yes             Yes                      No
# 5218        Yes      Yes             Yes                      No
# 6670        Yes      Yes             Yes                     Yes
# 6754         No      Yes             Yes                     Yes
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 753                  No      No internet service  No internet service
# 936                 DSL                      Yes                  Yes
# 1082                 No      No internet service  No internet service
# 1340                DSL                      Yes                  Yes
# 3331                 No      No internet service  No internet service
# 3826                 No      No internet service  No internet service
# 4380                 No      No internet service  No internet service
# 5218                 No      No internet service  No internet service
# 6670                DSL                       No                  Yes
# 6754                DSL                      Yes                  Yes
#
#       HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 753   No internet service  No internet service  No internet service
# 936                   Yes                   No                  Yes
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                   No                  Yes                   No
#
#      HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 753   No internet service         Two year                 No
# 936                   Yes         Two year                 No
# 1082  No internet service         Two year                 No
# 1340                   No         Two year                 No
# 3331  No internet service         Two year                 No
# 3826  No internet service         Two year                 No
# 4380  No internet service         Two year                 No
# 5218  No internet service         One year                Yes
# 6670                   No         Two year                 No
# 6754                   No         Two year                Yes
#
#                   PaymentMethod  Churn
# 753                Mailed check      0
# 936                Mailed check      0
# 1082               Mailed check      0
# 1340    Credit card (automatic)      0
# 3331               Mailed check      0
# 3826               Mailed check      0
# 4380               Mailed check      0
# 5218               Mailed check      0
# 6670               Mailed check      0
# 6754  Bank transfer (automatic)      0

# %% [markdown]
# Obviously it's new clients who did not make first payment yet. Let's fill them with zeroes.

# %%
data["TotalSpent"] = data.TotalSpent.fillna(0).astype(float)
X_test["TotalSpent"] = X_test.TotalSpent.fillna(0).astype(float)

# %%
patterns = {
    "No": 0,
    "No internet service": 0,
    "No phone service": 0,
    "Yes": 1,
    "Male": 0,
    "Female": 1,
    "DSL": 1,
    "Fiber optic": 2,
    "Month-to-month": 0,
    "One year": 1,
    "Two year": 2,
    "Credit card (automatic)": 0,
    "Bank transfer (automatic)": 1,
    "Mailed check": 2,
    "Electronic check": 3,
}
X_train = data.replace(patterns).drop(target, axis=1)
y_train = data[target]
X_test = X_test.replace(patterns)

# %% [markdown]
# It makes possible to draw correlation heatmap.

# %%
sns.heatmap(data=pd.concat([X_train, y_train], axis=1).corr(),
            annot=True,
            cmap="coolwarm",
            center=0,
            ax=plt.subplots(figsize=(15,10))[1]);

# %% [markdown]
# HasContractPhone has strongest correlation with target (-0.4), then goes ClientPeriod(-0.35), and HasInternetService (0.31). In first two cases correlation is negative. It's positive in the last. It's tempting to think that provider gained very loyal phone users over the years, then decided to go to internet market and didn't do so well...

# %% [markdown]
# Let's evaluate feature importance with RandomForest.

# %%
clf = RandomForestClassifier(n_estimators=2000, min_impurity_decrease=0.001)
clf.fit(X_train, y_train)
pd.DataFrame(clf.feature_importances_, index=X_train.columns, columns=["importance"]) \
    .sort_values("importance") \
    .plot(kind="barh", legend=False, figsize=(12, 8));
plt.title("Feature importance");

# %% [markdown]
# The chart confirms our observations.

# %% [markdown]
# Now let's do the same with a single DecisionTree.

# %%
clf = DecisionTreeClassifier(min_impurity_decrease=0.002)
clf.fit(X_train, y_train)
plt.figure(figsize=(20, 8))
plot_tree(clf, fontsize=14, feature_names=X_train.columns, filled=True)
plt.show()

# %% [markdown]
# Let's look at explained variance ratio.

# %%
X_train_std = StandardScaler().fit_transform(X_train)
pca = PCA()
X_train_pca = pca.fit_transform(X_train_std)
exp_var_pca = pca.explained_variance_ratio_
cum_sum_eigenvalues = np.cumsum(exp_var_pca)
plt.bar(range(0, len(exp_var_pca)), exp_var_pca, alpha=0.5, align="center", label="Individual explained variance")
plt.step(range(0, len(cum_sum_eigenvalues)), cum_sum_eigenvalues, where="mid", label="Cumulative explained variance")
plt.ylabel("Explained variance ratio")
plt.xlabel("Principal component index")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# I've commented out param ranges to save time and left only optimal one.

# %%
# %%time
PARAMS = {
    "model__C": [1.92],  # np.arange(0.001, 100, 0.001)
}
clf = Pipeline(steps=[
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(penalty="l1", solver="saga", max_iter=1000, random_state=42)),
])
grid_search = GridSearchCV(
    estimator=clf,
    param_grid=PARAMS,
    scoring="roc_auc",
    n_jobs=-1,
    cv=10,
    refit=True,
)
logreg = grid_search.fit(X_train, y_train)
# Out:
# CPU times: user 798 ms, sys: 50 ms, total: 848 ms
# Wall time: 5.67 s

# %%
print(f"best score: {logreg.best_score_}")
print(f"best params: {logreg.best_params_}")
# Out:
# best score: 0.8469894928378491
# best params: {'model__C': 1.92}

# %%
submission = pd.read_csv(INPUT_DIR + "submission.csv")
submission["Churn"] = logreg.predict_proba(X_test)[:, 1]
submission.to_csv(OUTPUT_DIR + "logreg.csv", index=False)

# %% [markdown]
# # CatBoost

# %%
catboost = CatBoostClassifier(
    cat_features=cat_cols,
    logging_level="Silent",
    eval_metric="AUC:hints=skip_train~false",
    grow_policy="Lossguide",
    metric_period=1000,
    random_seed=42,
    loss_function='CrossEntropy',
#     task_type='GPU',
    early_stopping_rounds=10
)

PARAMS = {
    "n_estimators": [300, 500, 700, 1000],  # [5, 10, 20, 30, 40, 50, 70, 100, 150, 200, 250, 300, 500, 1000],
    "learning_rate": [0.05],  # [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.02, 0.04, 0.05, 0.1, 0.2, 0.3, 0.5],
    "max_depth": [4],  # np.arange(4, 20, 1),
    "l2_leaf_reg": [10],  # np.arange(0.1, 1, 0.05),
    "subsample": [0.6],  # [3, 5, 7, 10],
#     "random_strength": [2, 5, 8],  # [1, 2, 5, 10, 20, 50, 100],
    "min_data_in_leaf": [100],  # np.arange(10, 1001, 10),
#     'task_type': ['GPU'],
#     'early_stopping_rounds': [10],
}
catboost.grid_search(PARAMS, X_train, y_train, cv=5, plot=True, refit=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	loss: 0.8514962	best: 0.8514962 (0)	total: 3s	remaining: 9s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 1:	loss: 0.8514962	best: 0.8514962 (0)	total: 5.96s	remaining: 5.96s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 2:	loss: 0.8514962	best: 0.8514962 (0)	total: 8.97s	remaining: 2.99s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 3:	loss: 0.8514962	best: 0.8514962 (0)	total: 12.3s	remaining: 0us
# Estimating final quality...
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# {'params': {'min_data_in_leaf': 100,
#   'depth': 4,
#   'l2_leaf_reg': 10,
#   'iterations': 300,
#   'subsample': 0.6,
#   'learning_rate': 0.05},
#  'cv_results': defaultdict(list,
#              {'iterations': [0, 299],
#               'test-AUC-mean': [0.7971549826075373, 0.8254531486873746],
#               'test-AUC-std': [0.022468140284466386, 0.03318715377654078],
#               'train-AUC-mean': [0.8027779155895101, 0.8347616359171226],
#               'train-AUC-std': [0.007850694404817702, 0.04198420509413435],
#               'test-CrossEntropy-mean': [0.6647292543686211,
#                0.5587919518056232],
#               'test-CrossEntropy-std': [0.0016503688974002064,
#                0.1447430898208645],
#               'train-CrossEntropy-mean': [0.6643365648017376,
#                0.547398207840285],
#               'train-CrossEntropy-std': [0.0008856356107208234,
#                0.15988805582078694]})}

# %%
print("Best score:", end=' ')
pprint(catboost.best_score_)
best_params = catboost.get_params()
for f in ("cat_features", "logging_level", "eval_metric"):
    best_params.pop(f)
print("Best params:", end=' ')
pprint(best_params)
# Out:
# Best score: {'learn': {'AUC': 0.8803974055152455, 'CrossEntropy': 0.37270349415333187}}
# Best params: {'depth': 4,
#  'early_stopping_rounds': 10,
#  'grow_policy': 'Lossguide',
#  'iterations': 300,
#  'l2_leaf_reg': 10,
#  'learning_rate': 0.05,
#  'loss_function': 'CrossEntropy',
#  'metric_period': 1000,
#  'min_data_in_leaf': 100,
#  'random_seed': 42,
#  'subsample': 0.6}

# %%
submission = pd.read_csv(INPUT_DIR + "submission.csv")
submission["Churn"] = catboost.predict_proba(X_test)[:, 1]
submission.to_csv(OUTPUT_DIR + "catboost.csv", index=False)

# %% [markdown]
# # KNN

# %%
numeric_transformer = Pipeline(steps=[
    ("scaler", StandardScaler())
])
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_cols),
        ("cat", OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)
PARAMS = {
    "model__n_neighbors": [44],  # range(1, 100),
    "model__metric": ["manhattan"],  # ["cityblock", "cosine", "euclidean", "l1", "l2", "manhattan", "nan_euclidean"],
}

clf = Pipeline(steps=[
    ("preproc", preprocessor),
    ("model", KNeighborsClassifier()),
])
    
grid_search = GridSearchCV(
    estimator=clf,
    param_grid=PARAMS,
    scoring="roc_auc",
    n_jobs=-1,
    cv=10,
    refit=True,
)
knn = grid_search.fit(X_train, y_train)

# %%
print(f"best score: {knn.best_score_}")
print(f"best params: {knn.best_params_}")
# Out:
# best score: 0.843178445942379
# best params: {'model__metric': 'manhattan', 'model__n_neighbors': 44}

# %%
submission = pd.read_csv(INPUT_DIR + "submission.csv")
submission["Churn"] = knn.predict_proba(X_test)[:, 1]
submission.to_csv(OUTPUT_DIR + "knn.csv", index=False)

# %% [markdown]
# # Random Forest

# %%
PARAMS = {
    "min_samples_split": [9],  # range(2, 200),
    "min_samples_leaf": [18],  # range(1, 200),
}
clf = RandomForestClassifier(n_estimators=200, random_state=42)

grid_search = GridSearchCV(clf, PARAMS, scoring="roc_auc", cv=5)
rf = grid_search.fit(X_train, y_train);

# %%
print(f"Best score: {rf.best_score_}")
print(f"Best params: {rf.best_params_}")
# Out:
# Best score: 0.8769306508549957
# Best params: {'min_samples_leaf': 18, 'min_samples_split': 9}

# %%
submission = pd.read_csv(INPUT_DIR + "submission.csv")
submission["Churn"] = rf.predict_proba(X_test)[:, 1]
submission.to_csv(OUTPUT_DIR + "rf.csv", index=False)

# %% [markdown]
# # Stacking

# %% [markdown]
# Finally let's create stacking ensemble from all these models.

# %%
meta = CatBoostClassifier(
    logging_level='Silent',
    eval_metric="AUC:hints=skip_train~false",
    metric_period=1000,
    random_seed=0,
    grow_policy="Depthwise",
    l2_leaf_reg=1,
    learning_rate=0.08,
    max_depth=10,
    min_data_in_leaf=10,
    n_estimators=10,
    random_strength=11,
    subsample=0.1,
)
stacking = StackingClassifier(
    estimators=[
        ("logreg", logreg),
        ("knn", knn),
        ("rf", rf),
        ("catboost", catboost),
    ],
    final_estimator=meta,
    n_jobs=-1,
)

stacking.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('logreg',
#                                 GridSearchCV(cv=10,
#                                              estimator=Pipeline(steps=[('scaler',
#                                                                         StandardScaler()),
#                                                                        ('model',
#                                                                         LogisticRegression(max_iter=1000,
#                                                                                            penalty='l1',
#                                                                                            random_state=42,
#                                                                                            solver='saga'))]),
#                                              n_jobs=-1,
#                                              param_grid={'model__C': [1.92]},
#                                              scoring='roc_auc')),
#                                ('knn',
#                                 GridSearchCV(cv=10,
#                                              estimator=Pipeline(steps=[('preproc',
#                                                                         ColumnTransformer(trans...
#                                                          'model__n_neighbors': [44]},
#                                              scoring='roc_auc')),
#                                ('rf',
#                                 GridSearchCV(cv=5,
#                                              estimator=RandomForestClassifier(n_estimators=200,
#                                                                               random_state=42),
#                                              param_grid={'min_samples_leaf': [18],
#                                                          'min_samples_split': [9]},
#                                              scoring='roc_auc')),
#                                ('catboost',
#                                 <catboost.core.CatBoostClassifier object at 0x7f0c55145f10>)],
#                    final_estimator=<catboost.core.CatBoostClassifier object at 0x7f0c5513df90>,
#                    n_jobs=-1)

# %% [markdown]
# # Final Prediction

# %%
best_model = stacking

# %%
y_pred = best_model.predict_proba(X_test)[:, 1]
submission = pd.read_csv(INPUT_DIR + "./submission.csv")
submission['Churn'] = y_pred
submission.to_csv("submission.csv", index=False)

# %%
# delete temporary files
# !rm -r catboost_info

# %% [markdown]
# <div class="alert alert-success">
#     <h3 align="center" style="color:darkgreen;">Good Luck!</h3>
# </div>
