# %% [markdown]
# Создайте функцию play_intro(), которая печатает на экран строку: "🎸 Джанг-джанг!". Вызовите её.

# %%
# Ваш код здесь

# %% [markdown]
# Напишите функцию welcome(name), которая принимает имя и печатает "Привет, <имя>! Давай сыграем рок!". Вызовите её с вашим именем.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте функцию add(a, b), которая возвращает сумму двух чисел. Вызовите её и результат сохраните в переменную result. Напечатайте result.

# %%
# Ваш код здесь

# %% [markdown]
# Напишите функцию is_even(n), которая возвращает True, если число чётное, и False – если нечётное. Проверьте её на числах 4 и 7 (напечатайте результат).

# %%
# Ваш код здесь

# %% [markdown]
# Создайте функцию power(base, exponent=2), которая возводит base в степень exponent. Если exponent не передан, используется квадрат. Вызовите её с одним аргументом 5 и с двумя аргументами 2 и 4.

# %%
# Ваш код здесь

# %% [markdown]
# Напишите функцию sum_all(*args), которая принимает любое количество чисел и возвращает их сумму. Проверьте на 1,2,3 и 10,20,30,40.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте функцию print_info(**kwargs), которая печатает все переданные именованные аргументы в формате "ключ: значение". Вызовите с name="Дима", age=28, city="Москва".

# %%
# Ваш код здесь

# %% [markdown]
# Глобальная переменная counter = 0. Создайте функцию increment(), которая увеличивает counter на 1 (используйте global). Вызовите её два раза и напечатайте counter.

# %%
counter = 0
# Ваш код здесь

# %% [markdown]
# Вложенная функция: напишите outer(), внутри которой есть переменная x = 10. Внутри outer() определите inner(), которая увеличивает x на 5 с помощью nonlocal. Вызовите inner() и напечатайте x из outer.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте лямбда-функцию, которая возвращает квадрат числа. Присвойте её переменной square. Вызовите для числа 7.

# %%
# Ваш код здесь

# %% [markdown]
# Используя map() и лямбду, преобразуйте список [1,2,3,4] в список квадратов. Результат сохраните в squared_list.

# %%
# Ваш код здесь

# %% [markdown]
# С помощью filter() и лямбды оставьте в списке [10,15,21,30,35,42] только числа, кратные 3.

# %%
# Ваш код здесь

# %% [markdown]
# Напишите функцию make_multiplier(n), которая возвращает функцию, умножающую свой аргумент на n. Создайте double = make_multiplier(2) и triple = make_multiplier(3). Вызовите их для числа 5.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте декоратор stars, который выводит строку из звёздочек до и после вызова декорируемой функции. Примените его к функции hello(), которая печатает "Привет, мир!".

# %%
# Ваш код здесь

# %% [markdown]
# Создайте декоратор repeat(times), который повторяет вызов функции times раз. Примените к функции say_hello(), которая печатает "Hello!". Запустите с repeat(3).

# %%
# Ваш код здесь

# %% [markdown]
# Напишите генератор countdown(n), который выдаёт числа от n до 1 (включительно). Используйте его в цикле for для n=5.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте генератор infinite_numbers(), который бесконечно выдаёт целые числа, начиная с 0. Используйте next() три раза, чтобы получить первые три числа.

# %%
# Ваш код здесь

# %% [markdown]
# Создайте асинхронную функцию async_hello(), которая печатает "Старт", ждёт 1 секунду через await asyncio.sleep(1), потом печатает "Финиш". Запустите её через asyncio.run().

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio

# Ваш код здесь

# %% [markdown]
# Напишите две асинхронные функции: boil_water() (ждёт 2 секунды, возвращает "кипяток") и cut_tomatoes() (ждёт 1 секунду, возвращает "помидоры"). В функции cook() запустите их параллельно через asyncio.gather(), результат напечатайте.

# %%
# Ваш код здесь
