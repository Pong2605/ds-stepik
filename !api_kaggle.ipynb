# %%
# Загрузка датасета
# https://github.com/Kaggle/kaggle-api
#--------------------------------------------


# !pip install kaggle --upgrade

# %%
# from google.colab import drive
# drive.mount('/gdrive')
# !rm -r /content/sample_data

# drive_path = "/gdrive/My Drive/<Папка на google диске, в которой лежит kaggle.json>"

# %%
# kaggle.json копируется с google диска



# !mkdir ~/.kaggle/
# !cp "{drive_path}/kaggle.json" ~/.kaggle/

# !kaggle competitions download -c advanced-dls-spring-2021

# !unzip -q advanced-dls-spring-2021.zip -d /content/data
# !rm advanced-dls-spring-2021.zip
