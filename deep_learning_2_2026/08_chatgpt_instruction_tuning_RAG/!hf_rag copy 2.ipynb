# %% [markdown]
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>

# %% [markdown]
# # Домашнее задание. RAG.

# %% [markdown]
# В этом домашнем задании вам предстоит создать туристический RAG, провести EDA и проявить креатив! :)
#
# Вам дан набор данных, содержащий информацию о памятниках, архитектуре и других значимых местах. В данных есть:
# * название достопримечательности;
# * идентификатор на WikiData;
# * город расположения;
# * координаты долготы и широты;
# * описание (извлеченное из WikiData);
# * изображение в формате base64;
# * сгенерированное описание изображения (генерация с помощью модели BLIP).
#
# Некоторые из памятников могут встречаться несколько раз, но с различными изображениями, из которых не все могут быть качественными. Для компенсации этого даны текстовые описания.

# %% [markdown]
# Часть данных взята с Национальной технологической олимпиады студентов по CV. Базовое решение предполагает использование мультимодального ru-CLIP. Но в данном домашнем задании предлагается решить эту задачу творчески, используя NLP подход.

# %% [markdown]
# ## Установка и импорт библиотек

# %%
# !pip install -q gdown torch transformers transformers accelerate bitsandbytes langchain sentence-transformers faiss-gpu openpyxl datasets langchain-community ragatouille umap-learn

# %%
# !pip install --ignore-installed huggingface-hub==0.20.3

# %%
# # После перезапуска ядра
# !pip uninstall huggingface-hub -y
# !pip install huggingface-hub==0.20.3

# # Проверка версии
# import huggingface_hub
# print(f"Installed version: {huggingface_hub.__version__}")

# %%
# !pip install --upgrade sentence-transformers

# %%
# !pip install pacmap

# %%
# !pip install -U bitsandbytes>=0.46.1

# %%
# !pip uninstall langchain-community -y
# !pip install langchain-community
# !pip install --upgrade sentence-transformers

# %%
# !pip install ragatouille

# %%
import warnings

# from huggingface_hub import hf_hub_download
# import huggingface_hub

# huggingface_hub.cached_download = hf_hub_download

warnings.filterwarnings('ignore')

import gdown
import pandas as pd
from tqdm.notebook import tqdm
from typing import Optional, List, Tuple
import matplotlib.pyplot as plt
from langchain.docstore.document import Document as LangchainDocument
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer
from langchain.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores.utils import DistanceStrategy
import numpy as np
import plotly.express as px
from transformers import pipeline
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, AutoModelForSeq2SeqLM
# from ragatouille import RAGPretrainedModel
import os
import sys

#------------------------------------------------------------------------------------
# from langchain.text_splitter import ... # выберите другую стратегию разбивки на чанки
from langchain.text_splitter import RecursiveCharacterTextSplitter

from sklearn.feature_extraction.text import TfidfVectorizer
import re
import string
import nltk
import pymorphy2
from nltk.corpus import stopwords
from langchain_classic.retrievers import ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import CrossEncoderReranker
from FlagEmbedding import FlagReranker
import faiss
import gc
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import umap
from langchain_community.cross_encoders import HuggingFaceCrossEncoder
from transformers import Pipeline

pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 500)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Используется устройство: {device}')
# Out:
# Используется устройство: cuda

# %%
os.makedirs('content', exist_ok=True)
os.makedirs('models', exist_ok=True)

# %%
# !nvidia-smi

# %% [markdown]
# ## Загрузка данных (4 балла)

# %%
# url = 'https://drive.google.com/uc?id=1P1BsvI2jPN3fEqjc2YZxmQ-MTs22WVUk'
# output = 'file.csv'

# gdown.download(url, output, quiet=False)

# data = pd.read_csv('file.csv')

# %%
# Загрузка данных

file_id = '1P1BsvI2jPN3fEqjc2YZxmQ-MTs22WVUk'
output = 'content/file.csv'

if not os.path.exists(output):
    gdown.download(id=file_id, output=output, quiet=False)

# %%
data = pd.read_csv(output).drop('Unnamed: 0', axis=1, errors='ignore')

# %%
# data.sample(500)
data.sample(3)
# Out:
#                       Name   WikiData             City        Lon        Lat  \
# 11104      Демидовский сад  Q19908952        Ярославль  39.897240  57.625038
# 2894          Дом Артистов  Q19615085     Екатеринбург  60.614166  56.839169
# 5458   Чкаловская лестница   Q4516884  Нижний Новгород  44.009453  56.330479
#
#                                           description  \
# 11104                                 Демидовский сад
# 2894                           здание в Екатеринбурге
# 5458   лестница на Волжском откосе в Нижнем Новгороде
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      image  \
# 11104  ......
# 2894   ......
# 5458   ......
#
#                                                                  en_txt
# 11104      there is a statue in the middle of a park with a clock on it
# 2894                    arafed view of a city with a river and a bridge
# 5458   nighttime view of a city with a long staircase going up the hill

# %%
data['City'].unique()
# Out:
# <ArrowStringArray>
# ['Екатеринбург', 'Нижний Новгород', 'Владимир', 'Ярославль']
# Length: 4, dtype: str

# %% [markdown]
# Проверим датасет на предмет пропусков

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14634 entries, 0 to 14633
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         14634 non-null  str
#  1   WikiData     12078 non-null  str
#  2   City         14634 non-null  str
#  3   Lon          14634 non-null  float64
#  4   Lat          14634 non-null  float64
#  5   description  12078 non-null  str
#  6   image        14634 non-null  str
#  7   en_txt       14634 non-null  str
# dtypes: float64(2), str(6)
# memory usage: 641.0 MB

# %%
data.isna().sum()
# Out:
# Name              0
# WikiData       2556
# City              0
# Lon               0
# Lat               0
# description    2556
# image             0
# en_txt            0
# dtype: int64

# %% [markdown]
# Удалим строки с пропусками в WikiData и проверим датасет еще раз на предмет пропусков

# %%
data = data.dropna(subset=['WikiData'])

data.isna().sum()
# Out:
# Name           0
# WikiData       0
# City           0
# Lon            0
# Lat            0
# description    0
# image          0
# en_txt         0
# dtype: int64

# %%
# sorted(data['WikiData'].unique(), reverse=True)
# sorted(data['description'].unique(), reverse=False)
sorted(data['en_txt'].unique(), reverse=True)
# Out:
# ['прррмомоннннннннннн',
#  'yellow house with a black roof and a white fence',
#  'yellow flowers in front of a brick building with a clock tower',
#  'yellow church with blue domes and a clock tower in a city',
#  'yellow church with a golden dome on a sunny day',
#  'yellow church with a golden dome on a cloudy day',
#  'yellow church with a golden dome and a steeple on a street corner',
#  'yellow church with a golden dome and a cross on top',
#  'yellow church with a blue dome and a cross on the front',
#  'yellow bus parked in front of a large yellow building with a green roof',
#  'yellow building with white trim and windows on a sunny day',
#  'yellow building with white trim and windows on a street corner',
#  'yellow building with white trim and windows in winter time',
#  'yellow building with white trim and windows in snow covered area',
#  'yellow building with white trim and windows and a sign on the front',
#  'yellow building with white trim and windows',
#  'yellow building with white trim and columns on a snowy day',
#  'yellow building with white trim and columns',
#  'yellow building with white trim and arched windows on a sunny day',
#  'yellow building with white trim and arched windows in a city',
#  'yellow building with white trim and arched windows and a yellow car parked in front',
#  'yellow building with white pillars and a brick walkway in front of it',
#  'yellow building with white columns and pillars',
#  'yellow building with white columns and a green roof',
#  'yellow building with white columns and a balcony on a sunny day',
#  'yellow building with two towers and a yellow dome',
#  'yellow building with two towers and a golden dome',
#  'yellow building with two towers and a gold dome',
#  'yellow building with two towers and a clock on top of it',
#  'yellow building with green roof and white trim',
#  'yellow building with green roof and white columns',
#  'yellow building with green roof and green roofing',
#  'yellow building with green domes and a green roof',
#  'yellow building with columns and pillars on a street corner',
#  'yellow building with columns and a white door on a street',
#  'yellow building with columns and a green roof on a street corner',
#  'yellow building with columns and a green roof on a street',
#  'yellow building with columns and a brown door in front of it',
#  'yellow building with blue windows and a red door on a street',
#  'yellow building with arched windows and a green roof',
#  'yellow building with a white trim and a brown door',
#  'yellow building with a white roof and a green lawn',
#  'yellow building with a white and gold dome on top of it',
#  'yellow building with a steeple and a cross on top',
#  'yellow building with a sign that says metropolitan',
#  "yellow building with a sign that says bottroonirchich mark mark's method",
#  'yellow building with a sign on top of it that says hotel',
#  'yellow building with a sign on the front of it',
#  'yellow building with a sign and a sign post in front of it',
#  'yellow building with a red door and windows on a snowy day',
#  'yellow building with a red door and a clock on the front',
#  'yellow building with a lot of windows and a lot of cars',
#  'yellow building with a large flower garden in front of it',
#  'yellow building with a green roof and a white door',
#  'yellow building with a green roof and a white car parked in front of it',
#  'yellow building with a green roof and a clock tower',
#  'yellow building with a golden dome on top of it',
#  'yellow building with a golden dome and a horse drawn carriage',
#  'yellow building with a fountain in front of it and a tree in the middle',
#  'yellow building with a fountain in front of it and a fountain in the middle',
#  'yellow building with a fountain and statues in front of it',
#  'yellow building with a cross on the front of it',
#  'yellow building with a clock tower on top of it in a town',
#  'yellow building with a clock tower on top of it',
#  'yellow building with a clock tower and a walkway in front of it',
#  'yellow building with a clock tower and a flag on top',
#  'yellow building with a black roof and a fence in the snow',
#  'yellow building with a balcony and balconies on the top of it',
#  'yellow and white church with two golden domes and a cross on the top',
#  'yellow and white church with two gold domes and a green roof',
#  'yellow and white church with golden domes and a clock tower',
#  'yellow and white church with a green dome and a green roof',
#  'yellow and white church with a clock tower and a fence',
#  'yellow and white building with columns and windows on a street',
#  'yellow and white building with columns and a clock on the front',
#  'yellow and white building with a sign on the front of it',
#  'yellow and white building with a lot of windows and a fence',
#  'yellow and white building with a green roof and a green dome',
#  'yellow and white building with a green dome on top of it',
#  'yellow and white building with a green dome and a gold cross on top',
#  'yellow and white building with a clock tower and a woman walking by',
#  'yellow and white building with a clock on the front of it',
#  'yellow and red wooden house with a parking meter on the corner',
#  'yellow and green church with a steeple and a green roof',
#  'yellow and green building with two towers and a green roof',
#  'yellow and green building with a steeple and a clock tower',
#  'yellow and green building with a green trash can in front of it',
#  'yellow and green building with a green roof and a green roof',
#  'yellow and green building with a green dome and a blue roof',
#  'wrought iron fence with a green dome in the background',
#  'wrought iron fence surrounding a tree in front of a building',
#  'wrought iron fence surrounding a street with a building in the background',
#  'wrought iron fence surrounding a park with a building in the background',
#  'workers working on a large turbine in a factory',
#  'workers working on a large machine in a factory',
#  'woman taking a selfie in front of a mirror with her cell phone',
#  'woman standing on a stone wall overlooking a body of water',
#  'woman standing in front of a display case with a sculpture of a woman',
#  'woman sitting at a table with a laptop and a cup of coffee',
#  'woman sitting at a desk with a laptop and a book',
#  'woman in red jacket holding a large vase in front of a wall of musical instruments',
#  'woman in blue shirt using a machine to operate a machine',
#  'woman in black jacket listening to headphones in front of a black and white photograph',
#  'woman in a white top and floral skirt holding a box',
#  'woman holding a camera in front of a mirror with a blue light behind her',
#  'walkway in a park with trees and a statue in the distance',
#  'two women standing in a room with a table and pictures on the wall',
#  'two women looking at a model of the moon in a museum',
#  'two white lions laying on a roof in a zoo enclosure',
#  'two soccer players are playing soccer on a field with a crowd watching',
#  'two pictures of a tower with a clock on top of it',
#  'two pictures of a building that has been destroyed and a building that has been demolished',
#  'two pictures of a building and a car are hanging on a wall',
#  'two men sitting at a table with microphones in their hands',
#  'two men in uniform standing in front of a large sculpture',
#  'two men in suits sitting at a table signing papers',
#  'two men in hard hats looking at a turbine in a factory',
#  'two cheetah standing on rocks in a zoo enclosure',
#  'two boys in school uniforms are holding papers and looking at a tablet',
#  'trees with yellow leaves on them and a white church in the background',
#  'trees with yellow leaves in a park with a bench and a bench',
#  'trees with no leaves on them',
#  'trees lining the street in a park with a bench and a street light',
#  'trees lining the sidewalk in a park with people walking on the sidewalk',
#  'trees lining a path in a park with a lamp post',
#  'trees line the street in front of a white building with a clock tower',
#  'trees line the street in a park with a bench and a fire hydrant',
#  'trees line the edge of a grassy hill near a body of water',
#  'trees in the distance behind a grassy field with a dirt mound',
#  'trees in front of a building with cars parked in the parking lot',
#  'trees in front of a building with a clock tower in the middle',
#  'trees in front of a building with a clock tower',
#  'trees in front of a building with a clock on the top',
#  'trees in front of a building',
#  'trees in a park with a building in the background',
#  'trees in a park with a building and a clock tower',
#  'trees in a forest with a hill in the background',
#  'trees in a field with orange leaves and a cloudy sky',
#  'trees in a field with a bench and a bench in the middle',
#  'trees growing on the rocks in the woods near a blue sky',
#  'trees are turning colors in the fall and the water is still calm',
#  'trees are reflected in the water of a river in a city',
#  'trees are reflected in the water of a pond in front of a large house',
#  'trees are in the foreground of a large yellow building',
#  'trees are in the foreground of a city with a lake in the foreground',
#  'trees are in the foreground of a building with a street sign',
#  'trees are in the foreground of a building with a clock on a pedestal',
#  'trees are in the foreground and a monument in the background',
#  'trees are in the foreground and a clock tower is in the background',
#  'trees are in the foreground and a church in the background',
#  'trees are in the foreground and a building on the top of a hill',
#  'trees are in the foreground and a building is in the background',
#  'trees are in the foreground and a building in the background',
#  'trees are in the foreground',
#  'trees are in the background',
#  'trees are in front of the building',
#  'trees are in front of a white building with a clock tower',
#  'trees are in front of a red building with green domes',
#  'trees are in front of a large yellow building with a clock on the front',
#  'trees are in front of a church with a green roof',
#  'trees are in front of a church with a clock tower',
#  'trees are in front of a building with snow on the ground',
#  'trees are in front of a building with a snow covered sidewalk',
#  'trees are in front of a building with a sign on it',
#  'trees are in front of a building with a green roof',
#  'trees are in front of a building with a golden dome',
#  'trees are in front of a building with a clock tower',
#  'trees are in front of a building with a clock on the top',
#  'trees are growing on the side of the building',
#  'trees are growing on the side of a road in a park',
#  'trees are growing on the side of a hill near a castle',
#  'trees are growing on the hillside behind the castle',
#  'trees are growing on the hill behind the church',
#  'trees are growing in the park near a walkway and a building',
#  'trees and rocks in the woods with a bench and steps',
#  'trees and leaves are in the foreground of a pond and a bridge',
#  'trees and grass in a park with a clock tower in the background',
#  'trees and grass in a park with a brick path',
#  'trees and grass in a park with a bench and walkway',
#  'trees and grass in a field with a city in the background',
#  'trees and grass in a field with a blue sky in the background',
#  'trees and flowers in a park with benches and benches',
#  'trees and bushes surrounding a pond with a gazebo in the background',
#  'trees and bushes surrounding a pond and a church with a steeple',
#  'trees and bushes surrounding a lake with a building in the background',
#  'trees and bushes surround a walkway in a park with a statue',
#  'trees and bushes surround a park with a white building in the background',
#  'trees and bushes in front of a yellow building with a fountain',
#  'trees and bushes in front of a church with a steeple',
#  'trees and bushes in front of a building with a clothes line',
#  'trees and bushes in front of a brick wall with a clock tower',
#  'trees and bushes in a park with a bench and a building',
#  'trees and bushes in a field with a cloudy sky in the background',
#  'trees and a lake in the foreground with a church in the background',
#  'three priests standing in front of a building with a light pole',
#  'three men sitting at a table with microphones in front of them',
#  'three men in white lab coats are looking at a mirror',
#  'three men in military uniforms stand in front of a crowd',
#  'three men in military uniforms holding a certificate and a bouquet',
#  'three men in military uniforms are talking to each other',
#  'three men in military uniforms are looking at a cell phone',
#  'three girls sitting on a bed with a stuffed animal',
#  'three framed religious books on display in a glass case',
#  'three doctors standing in a hospital room with a surgical equipment',
#  'three doctors in white coats and masks stand in a room',
#  'they are two men standing in a room with a table full of clothes',
#  'they are all holding a child on their shoulders',
#  'there is a young girl standing on a bench in front of a building',
#  'there is a yellow taxi parked in front of a building',
#  'there is a yellow house with red trim and a red door',
#  'there is a yellow gate with a clock on top of it',
#  'there is a yellow gate with a clock on it in the middle of a street',
#  'there is a yellow fire hydrant sitting in front of a bar',
#  'there is a yellow church with two towers and a gate',
#  'there is a yellow car parked in front of a building',
#  'there is a yellow bus driving down the street in front of a building',
#  'there is a yellow building with two towers and a green roof',
#  'there is a yellow building with red trim and windows on the street',
#  'there is a yellow building with many windows and a tree',
#  'there is a yellow building with columns and a red stop light',
#  'there is a yellow building with a white window and a red stop sign',
#  'there is a yellow building with a white stripe on the side of it',
#  'there is a yellow building with a staircase going up to it',
#  'there is a yellow building with a sign that says ottohofen machachmeter',
#  'there is a yellow building with a sign on the top of it',
#  'there is a yellow building with a sign on the front of it',
#  'there is a yellow building with a red roof and a black fence',
#  'there is a yellow building with a red flag on the front',
#  'there is a yellow building with a green steeple and a clock tower',
#  'there is a yellow building with a green roof and a clock tower',
#  'there is a yellow building with a gate and a red fire hydrant',
#  'there is a yellow building with a clock tower in the middle of it',
#  'there is a yellow building with a clock on the top of it',
#  'there is a yellow building with a blue sign on the corner',
#  'there is a yellow building with a blue roof and a street sign',
#  'there is a yellow building with a blue dumpster in front of it',
#  'there is a yellow building with a black door and windows',
#  'there is a yellow building with a black door and a sign on the sidewalk',
#  'there is a yellow and white building with a sign on it',
#  'there is a yellow and white building with a green dome',
#  'there is a yellow and white building with a clock on top',
#  'there is a yellow and red building with a red roof',
#  'there is a yellow and green building with a green steeple',
#  'there is a yellow and green building with a green roof',
#  'there is a wooden wall with a shelf with spoons and spoons',
#  'there is a wooden structure with a steeple on top of it',
#  'there is a wooden structure with a cross on the top of it',
#  'there is a wooden path that is surrounded by trees',
#  'there is a wooden house with a snow covered roof and a window',
#  'there is a wooden house with a red roof and a tall building',
#  'there is a wooden house with a red roof and a red roof',
#  'there is a wooden house with a red roof and a large window',
#  'there is a wooden house with a red roof and a fence',
#  'there is a wooden house with a red roof and a brown roof',
#  'there is a wooden house with a fence and a gate',
#  'there is a wooden house with a door and a window',
#  'there is a wooden house with a bench in front of it',
#  'there is a wooden house with a balcony and stairs in the yard',
#  'there is a wooden fence and a wooden house in the background',
#  'there is a wooden deck with stairs leading to a house',
#  'there is a wooden deck with benches and a water slide',
#  'there is a wooden deck with benches and a fire pit',
#  'there is a wooden cross in front of a wooden building',
#  'there is a wooden church with two steeples on top of it',
#  'there is a wooden cart with a wooden seat in a museum',
#  'there is a wooden building with graffiti on it on the side of the street',
#  'there is a wooden building with a wooden fence and a wooden fence',
#  'there is a wooden building with a windmill on the roof',
#  'there is a wooden building with a steeple on the top of it',
#  'there is a wooden building with a steeple on the top',
#  'there is a wooden building with a sign on the front of it',
#  'there is a wooden building with a sign on it',
#  'there is a wooden building with a red roof and a red roof',
#  'there is a wooden building with a metal roof and a street sign',
#  'there is a wooden building with a lot of windows on the side of it',
#  'there is a wooden building with a large window next to a sidewalk',
#  'there is a wooden building with a green roof and a wooden fence',
#  'there is a wooden building with a brown roof and white trim',
#  'there is a wooden bed in a room with a canopy',
#  'there is a woman walking down the street with a stroller',
#  'there is a woman walking down the street in the snow',
#  'there is a woman walking down the street in front of a building',
#  'there is a woman walking down a path in a park',
#  'there is a woman walking down a path in a garden',
#  'there is a woman that is working on a piece of wood',
#  'there is a woman that is standing in a cemetery with a bat',
#  'there is a woman that is sitting on a rock by the water',
#  'there is a woman that is sitting down with a cell phone',
#  'there is a woman that is holding a pillow in her hand',
#  'there is a woman standing on a path in the woods',
#  'there is a woman standing next to a horse in a barn',
#  'there is a woman standing in front of a yellow building',
#  'there is a woman standing in front of a train with a wagon',
#  'there is a woman standing in front of a projector screen',
#  'there is a woman standing in front of a painting on a easel',
#  'there is a woman standing in front of a monument in a city',
#  'there is a woman standing in front of a building with a fountain',
#  'there is a woman standing in front of a building with a clock on it',
#  'there is a woman standing in a theatre with a microphone',
#  'there is a woman standing in a room with a lot of art',
#  'there is a woman standing in a room with a dog',
#  'there is a woman standing in a room with a chandelier',
#  'there is a woman standing in a park with a cell phone',
#  'there is a woman sitting on a couch with a laptop',
#  'there is a woman sitting on a bench in front of a television',
#  'there is a woman sitting on a bench in a park',
#  'there is a woman sitting at a table with a painting on it',
#  'there is a woman sitting at a table with a laptop',
#  'there is a woman crossing the street in front of a building',
#  'there is a woman and a child walking down a path',
#  'there is a woman and a child standing in the snow',
#  'there is a window on the side of a building with a plaque on it',
#  'there is a white truck parked in front of a building',
#  'there is a white tower with a cross on top in a park',
#  'there is a white tower with a clock on it in a park',
#  'there is a white structure in the middle of a lake',
#  'there is a white monument in the middle of a snowy park',
#  'there is a white lion standing in a zoo enclosure',
#  'there is a white house with a wooden door and a fence',
#  'there is a white house with a clock tower in the background',
#  'there is a white house with a black roof and a white fence',
#  'there is a white gazebo with a green roof on a brick walkway',
#  'there is a white gazebo with a green roof and a man standing on the side',
#  'there is a white gazebo with a green roof and a black fence',
#  'there is a white gazebo with a black roof on a hill',
#  'there is a white gazebo sitting on the side of a road',
#  'there is a white gazebo sitting on the shore of a lake',
#  'there is a white gazebo on the side of a road',
#  'there is a white gazebo in the middle of a grassy area',
#  'there is a white gate with a sign that says fort town gardens',
#  'there is a white fence with a gate and a tree',
#  'there is a white fence and a white house on a hill',
#  'there is a white clock tower with a bell on top of it',
#  'there is a white clock tower in the middle of a snowy park',
#  'there is a white clock tower in the middle of a park',
#  'there is a white church with two towers and a steeple',
#  'there is a white church with green domes on the side of the road',
#  'there is a white church with green domes on a grassy hill',
#  'there is a white church with green domes and a green roof',
#  'there is a white church with green domes and a fence',
#  'there is a white church with blue domes on the side of the road',
#  'there is a white church with blue domes on a cloudy day',
#  'there is a white church with blue domes and a blue roof',
#  'there is a white church with a steeple and a tree in front',
#  'there is a white church with a steeple and a green roof',
#  'there is a white church with a steeple and a clock tower',
#  'there is a white church with a steeple and a blue roof',
#  'there is a white church with a heart shaped statue in the middle',
#  'there is a white church with a green steeple on the side of it',
#  'there is a white church with a green steeple in the middle of a snowy field',
#  'there is a white church with a green steeple and a green dome',
#  'there is a white church with a green roof on a beach',
#  'there is a white church with a green roof and a steeple',
#  'there is a white church with a green roof and a blue dome',
#  'there is a white church with a golden dome on top',
#  'there is a white church with a gold steeple and a clock tower',
#  'there is a white church with a gold dome and a clock tower',
#  'there is a white church with a cross on the top of it',
#  'there is a white church with a clock tower in the middle of the park',
#  'there is a white church with a blue roof and a bell tower',
#  'there is a white church tower with a clock on it',
#  'there is a white church tower on the shore of a lake',
#  'there is a white church on the shore of a lake',
#  'there is a white building with two towers and a clock on the top',
#  'there is a white building with two towers and a blue roof',
#  'there is a white building with three towers and a blue roof',
#  'there is a white building with green roof and a green roof',
#  'there is a white building with green domes on the top of it',
#  'there is a white building with green domes on it',
#  'there is a white building with green domes and a clock tower',
#  'there is a white building with columns and a car parked on the street',
#  'there is a white building with blue domes on top of it',
#  'there is a white building with blue domes on it',
#  'there is a white building with blue domes in the snow',
#  'there is a white building with blue domes in the middle of a forest',
#  'there is a white building with blue domes and a yellow roof',
#  'there is a white building with blue domes and a fence',
#  'there is a white building with blue domes and a clock tower',
#  'there is a white building with a yellow awning on the front',
#  'there is a white building with a wooden door and a window',
#  'there is a white building with a tower on top of it',
#  'there is a white building with a tower and a clock tower',
#  'there is a white building with a steeple on top of it',
#  'there is a white building with a steeple on the top of it',
#  'there is a white building with a steeple and a steeple on the side',
#  'there is a white building with a steeple and a steeple on the front',
#  'there is a white building with a steeple and a clock tower',
#  'there is a white building with a staircase going up to it',
#  'there is a white building with a sign on the front of it',
#  'there is a white building with a green roof on a hill',
#  'there is a white building with a green roof next to a body of water',
#  'there is a white building with a green roof and a steeple',
#  'there is a white building with a green roof and a staircase',
#  'there is a white building with a green roof and a green roof',
#  'there is a white building with a green roof and a clock tower',
#  'there is a white building with a green roof and a blue roof',
#  'there is a white building with a green dome on top',
#  'there is a white building with a green dome and a green roof',
#  'there is a white building with a green dome and a gold cross on top',
#  'there is a white building with a golden dome on top',
#  'there is a white building with a gold dome on top',
#  'there is a white building with a gold dome in the middle of a garden',
#  'there is a white building with a gold dome and a bicycle parked in front of it',
#  'there is a white building with a fence and a building with a blue roof',
#  'there is a white building with a dome on top of it',
#  'there is a white building with a cross on top of it',
#  'there is a white building with a clock tower on the corner',
#  'there is a white building with a clock tower in the background',
#  'there is a white building with a clock on the top of it',
#  'there is a white building with a clock on the front of it',
#  'there is a white building with a brown roof on a street',
#  'there is a white building with a brown roof and a white tower',
#  'there is a white building with a brown roof and a red roof',
#  'there is a white building with a brown roof and a clock tower',
#  'there is a white building with a brown roof and a car parked in front of it',
#  'there is a white building with a brown roof and a brown door',
#  'there is a white building with a brown door and steps',
#  'there is a white building with a brown door and a brown fence',
#  'there is a white building with a blue steeple and a clock tower',
#  'there is a white building with a blue sign on it',
#  'there is a white building with a blue roof on a hill',
#  'there is a white building with a blue roof and a steeple',
#  'there is a white building with a blue roof and a green hedge',
#  'there is a white building with a blue roof and a blue dome',
#  'there is a white building with a blue dome on top',
#  'there is a white building with a black roof and a yellow top',
#  'there is a white building with a black roof and a white dome',
#  'there is a white building with a black roof and a street sign',
#  'there is a white building with a black roof and a staircase',
#  'there is a white building with a black roof and a clock tower',
#  'there is a white building with a black fence and a street sign',
#  'there is a white building with a black fence and a street light',
#  'there is a white building with a black fence and a body of water',
#  'there is a white building with a black and white striped pole',
#  'there is a white building with a black and white pole in front of it',
#  'there is a white building with a balcony on the top of it',
#  'there is a white building with a balcony and a balcony on the second floor',
#  'there is a white building on the side of the water',
#  'there is a white building on the hill with a car parked in front',
#  'there is a white bridge that is over a road',
#  'there is a white bench sitting in front of a yellow building',
#  'there is a white archway with a sign that says thomas e thomas memorial',
#  'there is a wall with a lot of pictures on it',
#  'there is a wall with a clock and a bunch of bells',
#  'there is a walkway with a bench and a bike on it',
#  'there is a walkway that leads to a playground with a slide',
#  'there is a walkway that leads to a park with a playground',
#  'there is a walkway that leads to a monument in a park',
#  'there is a walkway that leads to a monument in a cemetery',
#  'there is a walkway that leads to a gazebo in the park',
#  'there is a walkway that has a bench on it in the middle of a park',
#  'there is a walkway in the middle of a park with trees',
#  'there is a vintage photo of a woman in a park',
#  'there is a view of a town from a hill with a few people',
#  'there is a view of a park with a skateboard ramp and a lake',
#  'there is a view of a garden from a balcony of a house',
#  'there is a view of a city from a high up',
#  'there is a view of a church through a doorway of a building',
#  'there is a very tall building with a clock tower on top',
#  'there is a very ornate altar with flowers and a painting on the wall',
#  'there is a very old wooden house with a lot of windows',
#  'there is a very old house with a red trim on it',
#  'there is a very old building with a lot of windows',
#  'there is a vase with a floral design on it in a room',
#  'there is a typewriter and a book on a desk',
#  'there is a truck that is driving down the street',
#  'there is a truck parked on the side of the road in front of a building',
#  'there is a truck parked in front of a building with a truck in front of it',
#  'there is a truck parked in front of a building on the street',
#  'there is a tree that is in front of a building',
#  'there is a tree that is growing out of a rock in the woods',
#  'there is a tree that has fallen down in the park',
#  'there is a tree that has fallen down in front of a building',
#  'there is a tree that has been cut down in the woods',
#  'there is a tree that has been cut down and is in the yard',
#  'there is a tree in front of a building with snow on the ground',
#  'there is a train track going through a small town with a building in the background',
#  'there is a train that is sitting on the tracks in the room',
#  'there is a train that is parked in front of a building',
#  'there is a train that is going over a bridge over water',
#  'there is a train that is going over a bridge over a river',
#  'there is a train that is going down the tracks in the city',
#  'there is a train that is going down the tracks in front of a building',
#  'there is a train that is going down the tracks by the water',
#  'there is a train that is going by a building that is being demolished',
#  'there is a train that is going by a building on the tracks',
#  'there is a train that is going around a circle of tracks',
#  'there is a traffic light on the corner of a street',
#  'there is a tower with a spiral staircase in front of a building',
#  'there is a tower with a spiral staircase and a staircase leading to it',
#  'there is a tower with a clock on top of it in a city',
#  'there is a tower with a clock on top of it',
#  'there is a tiger walking in the snow near a building',
#  'there is a tiger that is sitting on a wooden platform',
#  'there is a tiger that is laying on a table in the grass',
#  'there is a tiger laying on a wooden platform in a zoo',
#  'there is a tiger laying on a platform in a zoo',
#  'there is a television set with a picture of a man on it',
#  'there is a teddy bear standing in the middle of a flower garden',
#  'there is a teddy bear sitting in a corner of a room',
#  'there is a teddy bear and a bear doll in a toy house',
#  'there is a tank that is sitting on the ground in front of a building',
#  'there is a tank that is sitting on a pedestal in the middle of a street',
#  'there is a tall white tower with a face on it',
#  'there is a tall white clock tower in front of a building',
#  'there is a tall tower with a steeple on top of it',
#  'there is a tall tower with a staircase going up to it',
#  'there is a tall tower with a gold top on a building',
#  'there is a tall tower with a flag on top of it',
#  'there is a tall tower with a face on it in the middle of a field',
#  'there is a tall tower with a clock on top of it',
#  'there is a tall tower with a clock on it on a hill',
#  'there is a tall tower with a clock on it next to a fence',
#  'there is a tall tower with a clock on it in the middle of a town',
#  'there is a tall tower with a clock on it in the middle of a park',
#  'there is a tall tower with a clock on it in the middle of a city',
#  'there is a tall tower with a clock on it in a town',
#  'there is a tall tower with a clock on it in a park',
#  'there is a tall statue with a clock on top of it',
#  'there is a tall red brick building with a clock on top',
#  'there is a tall monument with a gold angel on top',
#  'there is a tall monument with a clock on top of it',
#  'there is a tall monument in the middle of a park',
#  'there is a tall clock tower in the middle of a park',
#  'there is a tall building with two windows and a clock on it',
#  'there is a tall building with many windows on it',
#  'there is a tall building with a tower on the corner',
#  'there is a tall building with a steeple on the top',
#  'there is a tall building with a steeple and a bell tower',
#  'there is a tall building with a sign on the side of it',
#  'there is a tall building with a sign on the front of it',
#  'there is a tall building with a red roof and a tall building with a red roof',
#  'there is a tall building with a lot of windows on it',
#  'there is a tall building with a golden dome on top of it',
#  'there is a tall building with a clock tower on top of it',
#  'there is a tall building with a clock tower on the top',
#  'there is a tall building with a clock tower in the middle of it',
#  'there is a tall building with a clock tower and a cross on it',
#  'there is a tall building with a clock on the top of it',
#  'there is a tall building with a clock on the front of it',
#  'there is a tall building with a balcony on the corner of the street',
#  'there is a tall building with a balcony and a balcony on the second floor',
#  'there is a tall brick wall with a clock tower on it',
#  'there is a tall brick tower with a steeple on top of it',
#  'there is a tall brick tower with a green roof on a street corner',
#  'there is a tall brick tower with a green roof on a street',
#  'there is a tall brick tower with a green roof on a hill',
#  'there is a tall brick tower with a green roof and a staircase',
#  'there is a tall brick tower with a green roof and a clock on top',
#  'there is a tall brick tower with a green roof and a blue toilet',
#  'there is a tall brick tower with a green roof',
#  'there is a tall brick tower with a cross on top',
#  'there is a tall brick tower with a clock on top of it',
#  'there is a tall brick tower with a clock on top',
#  'there is a tall brick tower with a clock on it',
#  'there is a tall brick building with a steeple on top',
#  'there is a tall brick building with a steeple on the top',
#  'there is a tall brick building with a green roof on a street corner',
#  'there is a tall brick building with a green roof on a street',
#  'there is a tall brick building with a green roof and a clock on top',
#  'there is a tall brick building with a green roof',
#  'there is a tall brick building with a clock tower on top',
#  'there is a tall brick building with a clock on the top',
#  'there is a tall brick building with a clock on the front',
#  'there is a table with red chairs and a large painting on the wall',
#  'there is a table with chairs and a couch in a room',
#  'there is a table with a white table cloth on it',
#  'there is a table with a white table cloth and chairs',
#  'there is a table with a white table cloth and a white table cloth',
#  'there is a table with a white table cloth and a chair',
#  'there is a table with a white table cloth and a black piano',
#  'there is a table with a vase on it in a room',
#  'there is a table with a vase of flowers on it',
#  'there is a table with a vase and a vase on it',
#  'there is a table with a variety of rocks and a lizard',
#  'there is a table with a table cloth and a basket on it',
#  'there is a table with a red table cloth and chairs in a room',
#  'there is a table with a mirror and a chair in a room',
#  'there is a table with a glass top in a room',
#  'there is a table with a computer and a book on it',
#  'there is a table with a book on it in a room',
#  'there is a table with a book and a vase on it',
#  'there is a table with a book and a lamp in a room',
#  'there is a table with a book and a candle on it',
#  'there is a table with a blue table cloth and a chair',
#  'there is a street with a white building and a white truck',
#  'there is a street with a red brick building and a white line',
#  'there is a street with a lot of buildings on it',
#  'there is a street with a fence and a building with a clock on it',
#  'there is a street with a car driving down it and a building in the background',
#  'there is a street with a building and a tree in the middle',
#  'there is a street with a building and a street light',
#  'there is a street with a building and a clock tower in the background',
#  'there is a street with a building and a clock on it',
#  'there is a street with a building and a car parked on the side',
#  'there is a street view of a building with a clock tower',
#  'there is a street sign that is on the corner of a street',
#  'there is a street sign that is on the corner of a building',
#  'there is a street sign on the sidewalk next to a building',
#  'there is a street sign on the corner of a street',
#  'there is a street scene with a car and a building',
#  'there is a street light that is on the side of a building',
#  'there is a street light on the side of the road',
#  'there is a street light on the corner of a street in front of a building',
#  'there is a street light in the middle of a park',
#  'there is a stone with a plaque on it in the middle of a garden',
#  'there is a stone with a hole in it in the snow',
#  'there is a stone with a cross on it and a poem on it',
#  'there is a stone statue on the ground next to a trash can',
#  'there is a stone staircase going up to a rock formation',
#  'there is a stone staircase going up a hill in the woods',
#  'there is a stone seating area in the middle of a forest',
#  'there is a stone sculpture of a man on a brick path',
#  'there is a stone path leading to a memorial in a park',
#  'there is a stone monument with a clock on it in a park',
#  'there is a stone monument in the middle of a park',
#  'there is a stone grave with a cross on it in a cemetery',
#  'there is a stone bridge with graffiti on it over a frozen river',
#  'there is a stone bridge that is going over a small bridge',
#  'there is a stone bridge over a river with a stone arch',
#  'there is a statue of two people holding flags in front of a building',
#  'there is a statue of two men holding flags in a park',
#  'there is a statue of three men fighting each other',
#  'there is a statue of an eagle on top of a pole',
#  'there is a statue of a woman with a wreath on it',
#  'there is a statue of a woman sitting on a pile of luggage',
#  'there is a statue of a woman sitting on a bench in a garden',
#  'there is a statue of a woman in a park with a lamp post',
#  'there is a statue of a woman holding a flag in the snow',
#  'there is a statue of a woman holding a flag in a park',
#  'there is a statue of a woman holding a cross in a cemetery',
#  'there is a statue of a woman holding a child near a church',
#  'there is a statue of a woman holding a book in a snowy park',
#  'there is a statue of a woman holding a book in a park',
#  'there is a statue of a woman holding a bird in the snow',
#  'there is a statue of a woman holding a baby in a cemetery',
#  'there is a statue of a soldier standing next to a table',
#  'there is a statue of a man with a wreath on it',
#  'there is a statue of a man with a red hat and a red flower',
#  'there is a statue of a man with a horse head on it',
#  'there is a statue of a man with a hat and a jacket',
#  'there is a statue of a man with a hat and a coat',
#  'there is a statue of a man with a crown on it',
#  'there is a statue of a man with a cross and a cross on it',
#  'there is a statue of a man with a child and a man with a dog',
#  'there is a statue of a man with a bust on a pedestal',
#  'there is a statue of a man with a book on a street',
#  'there is a statue of a man with a beard on a pedestal',
#  'there is a statue of a man with a beard in the snow',
#  'there is a statue of a man with a beard in front of a building',
#  'there is a statue of a man with a beard in a park',
#  'there is a statue of a man with a beard in a cemetery',
#  'there is a statue of a man standing on top of a box',
#  'there is a statue of a man standing on a rock in the snow',
#  'there is a statue of a man standing on a rock in the middle of a park',
#  'there is a statue of a man standing on a rock in front of a building',
#  'there is a statue of a man standing on a rock in a park',
#  'there is a statue of a man standing on a rock',
#  'there is a statue of a man standing on a pedestal in the middle of a street',
#  'there is a statue of a man standing on a pedestal in front of a building',
#  'there is a statue of a man standing on a pedestal in a park',
#  'there is a statue of a man standing on a pedestal in a city',
#  'there is a statue of a man standing on a pedestal',
#  'there is a statue of a man standing on a bench',
#  'there is a statue of a man standing next to a building',
#  'there is a statue of a man standing in the snow',
#  'there is a statue of a man standing in the middle of a street',
#  'there is a statue of a man standing in the middle of a snowy park',
#  'there is a statue of a man standing in the middle of a park',
#  'there is a statue of a man standing in front of a wall',
#  'there is a statue of a man standing in front of a tree',
#  'there is a statue of a man standing in front of a sign',
#  'there is a statue of a man standing in front of a monument',
#  'there is a statue of a man standing in front of a forest',
#  'there is a statue of a man standing in front of a building',
#  'there is a statue of a man standing in front of a bench',
#  'there is a statue of a man standing in a square',
#  'there is a statue of a man standing in a park',
#  'there is a statue of a man standing in a fountain',
#  'there is a statue of a man sitting on a pedestal in the park',
#  'there is a statue of a man sitting on a pedestal in the middle of a street',
#  'there is a statue of a man sitting on a pedestal in the middle of a park',
#  'there is a statue of a man sitting on a pedestal in front of a building',
#  'there is a statue of a man sitting on a pedestal in a park',
#  'there is a statue of a man sitting on a pedestal',
#  'there is a statue of a man sitting on a grave',
#  'there is a statue of a man sitting on a chair in the woods',
#  'there is a statue of a man sitting on a bench next to a wall',
#  'there is a statue of a man sitting on a bench in the park',
#  'there is a statue of a man sitting on a bench in the grass',
#  'there is a statue of a man sitting on a bench in front of a monument',
#  'there is a statue of a man sitting on a bench in front of a building',
#  'there is a statue of a man sitting on a bench in a park',
#  'there is a statue of a man sitting on a bench',
#  'there is a statue of a man riding a horse with a man on it',
#  'there is a statue of a man riding a horse with a helmet on',
#  'there is a statue of a man riding a horse on a pedestal',
#  'there is a statue of a man riding a horse in the park',
#  'there is a statue of a man riding a horse in front of a building',
#  'there is a statue of a man on the side of a building',
#  'there is a statue of a man on a staircase in a building',
#  'there is a statue of a man on a skateboard in the middle of a street',
#  'there is a statue of a man on a rock in front of a building',
#  'there is a statue of a man on a pole in front of a building',
#  'there is a statue of a man on a pedestal with a smoke stack in the background',
#  'there is a statue of a man on a pedestal in the middle of a park',
#  'there is a statue of a man on a pedestal in front of a stop sign',
#  'there is a statue of a man on a pedestal in front of a building',
#  'there is a statue of a man on a pedestal in a park',
#  'there is a statue of a man on a horse in front of a building',
#  'there is a statue of a man on a bench in front of a building',
#  'there is a statue of a man in front of a building',
#  'there is a statue of a man in a suit on a pedestal',
#  'there is a statue of a man in a suit in front of a building',
#  'there is a statue of a man in a suit in a park',
#  'there is a statue of a man in a suit in a flower bed',
#  'there is a statue of a man in a suit and tie',
#  'there is a statue of a man in a park with trees',
#  'there is a statue of a man in a park with flowers',
#  'there is a statue of a man in a medieval armor room',
#  'there is a statue of a man in a coat on a pedestal',
#  'there is a statue of a man in a coat and a flag',
#  'there is a statue of a man in a coat and a building in the background',
#  'there is a statue of a man in a cage in a room',
#  'there is a statue of a man in a bust on a square',
#  'there is a statue of a man holding a woman on his back',
#  'there is a statue of a man holding a violin in a park',
#  'there is a statue of a man holding a sword in front of a building',
#  'there is a statue of a man holding a sword in a square',
#  'there is a statue of a man holding a sword in a plaza',
#  'there is a statue of a man holding a sword in a park',
#  'there is a statue of a man holding a knife in front of a building',
#  'there is a statue of a man holding a hat in front of a tree',
#  'there is a statue of a man holding a hat in a park',
#  'there is a statue of a man holding a gun in front of a building',
#  'there is a statue of a man holding a gun in a plaza',
#  'there is a statue of a man holding a gun in a park',
#  'there is a statue of a man holding a gun in a city square',
#  'there is a statue of a man holding a guitar in front of a building',
#  'there is a statue of a man holding a globe in the snow',
#  'there is a statue of a man holding a flag on a pedestal',
#  'there is a statue of a man holding a flag next to a clock tower',
#  'there is a statue of a man holding a flag in the snow',
#  'there is a statue of a man holding a flag in front of a building',
#  'there is a statue of a man holding a flag in a park',
#  'there is a statue of a man holding a flag and a woman holding a flag',
#  'there is a statue of a man holding a flag and a clock tower',
#  'there is a statue of a man holding a cigarette in front of a building',
#  'there is a statue of a man holding a child in front of a church',
#  'there is a statue of a man holding a child in a park',
#  'there is a statue of a man holding a briefcase in front of a building',
#  'there is a statue of a man holding a book in a plaza',
#  'there is a statue of a man holding a book in a park',
#  'there is a statue of a man holding a bird in the snow',
#  'there is a statue of a man holding a baseball bat in front of a building',
#  'there is a statue of a man holding a baseball bat in a room',
#  'there is a statue of a man holding a baseball bat in a park',
#  'there is a statue of a man holding a baseball bat',
#  'there is a statue of a man holding a baby in a park',
#  'there is a statue of a man holding a baby in a city square',
#  'there is a statue of a man and a woman on a train track',
#  'there is a statue of a man and a woman on a pedestal',
#  'there is a statue of a man and a woman on a horse',
#  'there is a statue of a man and a woman on a bridge',
#  'there is a statue of a man and a woman on a bench',
#  'there is a statue of a man and a woman in front of a building',
#  'there is a statue of a man and a woman in a park',
#  'there is a statue of a man and a woman holding flags',
#  'there is a statue of a man and a woman holding a flag',
#  'there is a statue of a man and a horse on a trailer',
#  'there is a statue of a man and a horse in front of a church',
#  'there is a statue of a lion with a shield on it',
#  'there is a statue of a horse on a pedestal in a park',
#  'there is a statue of a gun on display in front of a brick building',
#  'there is a statue of a dog on a pedestal in the snow',
#  'there is a statue of a cat in front of a building',
#  'there is a statue of a bird on top of a column',
#  'there is a statue of a bird in the middle of a park',
#  'there is a statue of a bear that is on a pedestal',
#  'there is a statue of a bear that is on a brick walkway',
#  'there is a statue of a bear in front of a building',
#  'there is a statue of a bear and a dog in a park',
#  'there is a statue in the middle of a walkway in front of a building',
#  'there is a statue in the middle of a street with a red flower bed',
#  'there is a statue in the middle of a square with a clock tower in the background',
#  'there is a statue in the middle of a park with trees',
#  'there is a statue in the middle of a park with people walking by',
#  'there is a statue in the middle of a park with benches',
#  'there is a statue in the middle of a park with a tree',
#  'there is a statue in the middle of a park with a fountain',
#  'there is a statue in the middle of a park with a clock on it',
#  'there is a statue in the middle of a park with a bench',
#  'there is a statue in the middle of a park surrounded by trees',
#  'there is a statue in the middle of a flower bed in front of a building',
#  'there is a statue in front of a building with a clock on it',
#  'there is a staircase with a railing and a vase on the table',
#  'there is a staircase leading to a second floor with pictures on the wall',
#  'there is a staircase leading to a large room with a red wall',
#  'there is a staircase in a house with a chandelier and pictures on the wall',
#  'there is a staircase in a building with a red fire hydrant',
#  'there is a staircase in a building with a painting on the wall',
#  'there is a staircase in a building with a chandelier and a chandelier',
#  'there is a spoon and spoon rest in a box on a table',
#  'there is a spiral staircase with a glass railing and a clock on the wall',
#  'there is a spiral staircase with a chandelier and a table',
#  'there is a snow covered wall with a tower in the background',
#  'there is a snow covered street with a building and a snowboard',
#  'there is a snow covered house with a tree in front of it',
#  'there is a snow covered field with a clock tower in the background',
#  'there is a snow covered building with a sign on it',
#  'there is a small wooden house with a wooden fence and a wooden gate',
#  'there is a small wooden house with a tree in the yard',
#  'there is a small wooden house with a red roof and a green fence',
#  'there is a small wooden house with a porch and a fence',
#  'there is a small wooden house with a porch and a bench',
#  'there is a small wooden house with a metal roof',
#  'there is a small wooden house with a green roof',
#  'there is a small wooden house with a gate and a fence',
#  'there is a small wooden house with a brown roof',
#  'there is a small wooden house with a balcony on the side of the street',
#  'there is a small wooden house on the corner of a street',
#  'there is a small wooden house in the snow with a tree',
#  'there is a small wooden house in the middle of a field',
#  'there is a small wooden church with two steeples on top of it',
#  'there is a small wooden church in the middle of a grassy field',
#  'there is a small wooden church in the middle of a field',
#  'there is a small wooden building with two towers in the middle of the woods',
#  'there is a small wooden building with two domes on top of it',
#  'there is a small wooden building with three spires on top of it',
#  'there is a small wooden building with a white roof',
#  'there is a small wooden building with a white fence and a clock tower',
#  'there is a small wooden building with a steeple on top',
#  'there is a small wooden building with a steeple on the top',
#  'there is a small wooden building with a sign on the front',
#  'there is a small wooden building with a sign on it',
#  'there is a small wooden building with a red roof and a red tin roof',
#  'there is a small wooden building with a red light on the corner',
#  'there is a small wooden building with a metal roof',
#  'there is a small wooden building with a dome on top',
#  'there is a small wooden building with a cross on the front',
#  'there is a small wooden building with a clock tower on top',
#  'there is a small wooden building with a clock on top',
#  'there is a small wooden building with a clock on the top of it',
#  'there is a small wooden building in the woods with a snow covered ground',
#  'there is a small white gazebo on the side of a lake',
#  'there is a small white church with blue domes on it',
#  'there is a small white church with a green roof',
#  'there is a small white building with blue domes on it',
#  'there is a small white building with a green roof on a hill',
#  'there is a small white building with a brown roof on a hill',
#  'there is a small white building with a bell tower in the middle of a field',
#  'there is a small white building in the middle of a park',
#  'there is a small white and orange building with two towers',
#  'there is a small tree that is growing out of a cement step',
#  'there is a small table with a cross on it in a church',
#  'there is a small river running through a city with a building on the side',
#  'there is a small red brick building with a clock on the top',
#  'there is a small red and white house with a green door',
#  'there is a small pond in front of a building with a bridge',
#  'there is a small playground in front of a large white building',
#  'there is a small plane that is parked in the grass',
#  'there is a small plane that is on top of a building',
#  'there is a small plane on top of a building in a city',
#  'there is a small pink building with a steeple on the top',
#  'there is a small pink building with a green roof and a steeple',
#  'there is a small monument with a star on it in a cemetery',
#  'there is a small monument in the middle of a street',
#  'there is a small log cabin with a sign on the front',
#  'there is a small log cabin with a red roof and a red door',
#  'there is a small house with a wooden fence in front of it',
#  'there is a small house with a tree in front of it',
#  'there is a small house with a red roof and a white fence',
#  'there is a small house with a red roof and a white door',
#  'there is a small house with a red roof and a fence',
#  'there is a small house with a porch and a covered patio',
#  'there is a small house with a porch and a bench in the yard',
#  'there is a small house with a ladder in the front yard',
#  'there is a small house with a hammock on the porch',
#  'there is a small house with a green roof and a red brick building',
#  'there is a small house with a green roof and a black gate',
#  'there is a small house with a blue roof and a black roof',
#  'there is a small house on the corner of a street',
#  'there is a small grave with a large head and a small grave with a large head',
#  'there is a small garden with a lot of flowers and trees',
#  'there is a small dog walking in front of a house',
#  'there is a small dining room with a couch and a table',
#  'there is a small church with two steeples on the top of it',
#  'there is a small church with two steeples on the roof',
#  'there is a small church with a steeple on the top of it',
#  'there is a small church with a steeple on the top',
#  'there is a small church with a steeple on the roof',
#  'there is a small church with a steeple and a steeple on the side',
#  'there is a small church with a steeple and a steeple on the roof',
#  'there is a small church with a steeple and a green roof',
#  'there is a small church with a steeple and a cross on top',
#  'there is a small church with a steeple and a cross on the top',
#  'there is a small church with a rainbow hose in front of it',
#  'there is a small church with a green steeple on the top',
#  'there is a small church with a green roof and a steeple',
#  'there is a small church with a cross on top of it',
#  'there is a small church with a cross on the top of it',
#  'there is a small church with a bell tower in the middle of a street',
#  'there is a small church on the corner of a street',
#  'there is a small church in the middle of a small town',
#  'there is a small cabin in the woods with a porch',
#  'there is a small building with a yellow dome on top',
#  'there is a small building with a tower on the top of it',
#  'there is a small building with a snow covered roof on the street',
#  'there is a small building with a small entrance in front of it',
#  'there is a small building with a sign on the front of it',
#  'there is a small building with a sign on it that says the museum',
#  'there is a small building with a red door and a window',
#  'there is a small building with a metal roof and a wooden fence',
#  'there is a small building with a metal roof and a sign on the front',
#  'there is a small building with a green roof and a tower',
#  'there is a small building with a golden dome on top',
#  'there is a small building with a flower pot on the side of it',
#  'there is a small building with a dome on the top of it',
#  'there is a small building with a cross on top of it',
#  'there is a small building with a clock tower on the side of it',
#  'there is a small building with a clock on the top of it',
#  'there is a small building with a clock on the side of it',
#  'there is a small brick structure with a dome on top',
#  'there is a small brick building with a steeple on the top',
#  'there is a small brick building with a green roof and a steeple',
#  'there is a small brick building with a green roof and a green door',
#  'there is a small brick building with a green roof',
#  'there is a small brick building with a clock tower on top',
#  'there is a small boy riding a toy car in front of a church',
#  'there is a small blue gazebo in the middle of a garden',
#  'there is a small black building with two steeples on top',
#  'there is a small bench in the grass next to a tree',
#  'there is a small bedroom with a bed and desk in it',
#  'there is a small bed in a small room with a window',
#  'there is a small bathroom with a sink and a window',
#  'there is a skateboarder riding on a ramp in front of a building',
#  'there is a skateboarder riding down a ramp outside of a building',
#  'there is a sign that says the hotel is hanging from the side of a building',
#  'there is a sign that says the city of st petersburg',
#  'there is a sign that says russian language on it',
#  'there is a sign that says restaurant in russian on the side of a building',
#  'there is a sign that says movini in russian on a building',
#  'there is a sign that says hopewood in front of a path',
#  'there is a sign that says georgetown street wrong 3',
#  'there is a sign that is on the side of the street',
#  'there is a sign that is on the side of a tree',
#  'there is a sign that is on the side of a dirt road',
#  'there is a sign that is in the snow by the trees',
#  'there is a sign that is in the middle of the forest',
#  'there is a sign that is in the grass near a tree',
#  'there is a sign that is in the grass near a path',
#  'there is a sign that is in the grass by a tree',
#  'there is a sign that is in front of a building',
#  'there is a sign on the wall that says befuha ciara teporm',
#  'there is a sign on the wall of a building that says occibik kyhila',
#  'there is a sign on the wall of a building that says it is a time',
#  'there is a sign on the wall of a building that says house of justice',
#  'there is a sign on the wall of a building that says',
#  'there is a sign on the sidewalk that says that there is a building',
#  'there is a sign on the side of a building that says, hotel maritana',
#  'there is a sign on the side of a building that says,',
#  'there is a sign on the side of a building that says old city',
#  'there is a sign on the side of a building that says miksish mikkish',
#  'there is a sign on the side of a building that says korphyc',
#  'there is a sign on the side of a building that says',
#  'there is a sign on the side of a bridge that says montaupoy hotel',
#  'there is a sign on the path that says the trail is not open',
#  "there is a sign on the fence that says,'the cemetery is closed '",
#  'there is a sign on the door of a building that says occinik',
#  'there is a sign on the building that says russian language',
#  'there is a sign on the building that says red lion',
#  'there is a sidewalk that has a sign on it that says the street is narrow',
#  'there is a sheep that is walking in the snow',
#  'there is a sculpture of a man sitting on a chair in a building',
#  'there is a sculpture of a man on a horse in a museum',
#  'there is a sculpture in the middle of a room with paintings on the wall',
#  'there is a sculpture in the middle of a brick walkway',
#  'there is a room with tables and chairs and a clock on the wall',
#  'there is a room with a window and a chair in it',
#  'there is a room with a wall with pictures and a coat rack',
#  'there is a room with a table, chairs, couches and paintings',
#  'there is a room with a table, chairs, and paintings on the walls',
#  'there is a room with a table, chairs, and a plant in it',
#  'there is a room with a table, chairs, and a mirror',
#  'there is a room with a table, chairs, and a dresser',
#  'there is a room with a table, chairs, and a couch',
#  'there is a room with a table, chairs, and a clock',
#  'there is a room with a table, chairs, and a cabinet',
#  'there is a room with a table, chair, and a clock',
#  'there is a room with a table, a clock, and a vase',
#  'there is a room with a table and pictures on the wall',
#  'there is a room with a table and chairs in it',
#  'there is a room with a table and chairs and a painting on the wall',
#  'there is a room with a table and chairs and a chandelier',
#  'there is a room with a table and a window with curtains',
#  'there is a room with a table and a wall with pictures',
#  'there is a room with a table and a lot of food on it',
#  'there is a room with a table and a large display case',
#  'there is a room with a table and a chair in it',
#  'there is a room with a stove, a table, and chairs',
#  ...]

# %%
# В колонке 'en_txt' замечено значение 'прррмомоннннннннннн', заменим его на моду

mask = data['en_txt'] == 'прррмомоннннннннннн'
name_field = data[mask]['Name'].iloc[0]
print(name_field)

mode_value = data[data['Name'] == name_field]['en_txt'].mode()[0]
print(mode_value)

data.loc[mask, 'en_txt'] = mode_value
# Out:
# Ярославский дворец молодёжи
# there is a building with a sign on the top of it

# %% [markdown]
# Для декодирования изображений, закодированных в формате base64, можно использовать следующий код:

# %%
import base64
import requests
import matplotlib.pyplot as plt
from PIL import Image
import PIL
from io import BytesIO

# %%
def get_image(data):
  image = Image.open(BytesIO(base64.b64decode(data))).convert('RGB')
  return image

# %%
get_image(data.sample(1)['image'].tolist()[0])
# Out:
# <PIL.Image.Image image mode=RGB size=427x320>

# %% [markdown]
# В данных есть выбросы — записи, не относящихся к туристическим или историческим объектам. Для очистки данных можно, например, использовать алгоритм TF-IDF: создаем корпус текстов из описаний, применяем TF-IDF, извлекаем наиболее редко или часто встречающиеся слова. Они могут указывать на мусорные данные, такие как мемы, баннеры или личные фото людей. После выделения подозрительных паттернов, можно провести ручную проверку и фильтрацию данных.
#
# Для дальнейшего тестирования и получения чистых сэмплов, рекомендуется взять не менее 100 чистых образцов со стратификацией по городу и названию места. Это можно сделать, выбрав случайным образом несколько образцов из каждой категории (город + название места), чтобы обеспечить равномерное представительство и разнообразие данных.
#
# **!! Важно:** Помните, что чистые сэмплы одного и того же места выдадут примерно одинаковое описание. Есть несколько стратегий, как повысить разнообразие ответов:
#
# - выбор одного самого лучшего:
#   - самое длинное описание
#   - самое подходящие по мнению LLM
# - конкатенация описаний (но важно не сконкатенировать слишком много)
#
# Изображения можно отдать в мета-данные.

# %% [markdown]
# Проверим датасет на предмет пропусков

# %% [markdown]
# Здесь предлагаем вам построить RAG с использованием моделей, которые не были представлены на семинаре (включая другие векторные базы данных). Можно воспользоваться материалами по этой ссылке: [data_connection/vectorstores](https://python.langchain.com/v0.1/docs/modules/data_connection/vectorstores/).
#
# !Важно, не забудьте отранжировать чанки текстов с помощью `ragatouille`. На практике порядок текстов в промпте влияет на точность ответа.

# %% [markdown]
# Вместо RAGatouille из ragatouille буду использорвать альтернативу (CrossEncoderReranker)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

tfidf = TfidfVectorizer(max_features=50, stop_words=['the', 'a', 'an', 'is', 'are', 'there'])
tfidf_matrix = tfidf.fit_transform(data['en_txt'].fillna(''))

avg_tfidf = np.array(tfidf_matrix.mean(axis=1)).flatten()
data['tfidf_score'] = avg_tfidf

threshold = np.percentile(avg_tfidf, 95)
data['is_outlier'] = data['tfidf_score'] > threshold

clean_data = data[~data['is_outlier']].copy()

# Альтернативный подход: создаём уникальный ключ и группируем вручную
clean_data['group_key'] = clean_data['City'].astype(str) + '||' + clean_data['Name'].astype(str)

# Выбираем по одному случайному образцу из каждой группы
stratified_data = clean_data.groupby('group_key', group_keys=False).apply(
    lambda x: x.sample(min(len(x), 1), random_state=42)
).reset_index(drop=True)

# Проверяем, есть ли столбец group_key перед удалением
if 'group_key' in stratified_data.columns:
    stratified_data = stratified_data.drop(columns=['group_key'])
else:
    print("Столбец 'group_key' уже был удалён")

print(f'После стратификации: {len(stratified_data)} уникальных мест')
print(f'Сохранились столбцы: {stratified_data.columns.tolist()}')

# Проверяем наличие City перед выводом
if 'City' in stratified_data.columns:
    print(f'Распределение по городам:')
    print(stratified_data["City"].value_counts())
else:
    print("ВНИМАНИЕ: столбец 'City' отсутствует в данных")
    print(f"Доступные столбцы: {stratified_data.columns.tolist()}")

# Ограничиваем до 100 записей
if len(stratified_data) > 100:
    stratified_data = stratified_data.sample(n=100, random_state=42)

# Создаём best_description - выбираем самое длинное описание для каждого названия
if 'en_txt' in stratified_data.columns and 'Name' in stratified_data.columns:
    stratified_data['desc_length'] = stratified_data['en_txt'].fillna('').astype(str).str.len()
    stratified_data = stratified_data.sort_values('desc_length', ascending=False)
    stratified_data = stratified_data.drop_duplicates(subset=["Name"], keep='first')
    stratified_data = stratified_data.drop(columns=['desc_length'])
else:
    print(f"Не хватает столбцов: en_txt={'en_txt' in stratified_data.columns}, Name={'Name' in stratified_data.columns}")

# Создание обогащённого текста
if 'Name' in stratified_data.columns and 'City' in stratified_data.columns and 'description' in stratified_data.columns:
    english_col = 'en_txt' if 'en_txt' in stratified_data.columns else 'englishText'
    
    stratified_data['fullText'] = (
        stratified_data["Name"].fillna('').astype(str) + '. ' +
        stratified_data["City"].fillna('').astype(str) + '. ' +
        stratified_data['description'].fillna('').astype(str) + ' ' +
        stratified_data[english_col].fillna('').astype(str)
    )
    
    stratified_data['fullText'] = stratified_data['fullText'].str.replace(r'\s+', ' ', regex=True).str.strip()
else:
    print("Не удалось создать fullText: отсутствуют необходимые столбцы")

print(f"Чистых записей: {len(clean_data)}")
print(f"Удалено выбросов: {data['is_outlier'].sum()}")
print(f"Итоговый размер sample: {len(stratified_data)}")

if 'Name' in stratified_data.columns and 'City' in stratified_data.columns and 'fullText' in stratified_data.columns:
    print(f"\nПример данных:\n{stratified_data[['Name', 'City', 'fullText']].head()}")
elif 'Name' in stratified_data.columns and 'City' in stratified_data.columns:
    print(f"\nПример данных (без fullText):\n{stratified_data[['Name', 'City', 'en_txt']].head()}")
else:
    print(f"\nПервые строки данных:\n{stratified_data.head()}")
# Out:
# Столбец 'group_key' уже был удалён
# После стратификации: 320 уникальных мест
# Сохранились столбцы: ['Name', 'WikiData', 'City', 'Lon', 'Lat', 'description', 'image', 'en_txt', 'tfidf_score', 'is_outlier']
# Распределение по городам:
# City
# Нижний Новгород    98
# Екатеринбург       97
# Ярославль          96
# Владимир           29
# Name: count, dtype: int64
# Чистых записей: 11474
# Удалено выбросов: 604
# Итоговый размер sample: 100
#
# Пример данных:
#                                           Name             City  \
# 78                       Площадь 1-й Пятилетки     Екатеринбург
# 167                                 Лицей № 82  Нижний Новгород
# 146              Дом Ермолаевых — П. Парфёнова  Нижний Новгород
# 119  №18 Фотографический музей «Дом Метенкова»     Екатеринбург
# 63                             Комсомолу Урала     Екатеринбург
#
#                                                                                                                                                       fullText
# 78     Площадь 1-й Пятилетки. Екатеринбург. городская площадь в Екатеринбурге there is a statue in the middle of a square with a clock tower in the background
# 167                      Лицей № 82. Нижний Новгород. Лицей № 82 "Школа баррикад" people standing outside of a building with balloons and balloons on the roof
# 146  Дом Ермолаевых — П. Парфёнова. Нижний Новгород. Дом Ермолаевых — П. Парфёнова arafed building with a television on top of it and a television on the roof
# 119     №18 Фотографический музей «Дом Метенкова». Екатеринбург. музей в Екатеринбурге there is a yellow building with a sign that says ottohofen machachmeter
# 63                                Комсомолу Урала. Екатеринбург. памятник в Екатеринбурге there is a statue of a man holding a flag and a woman holding a flag

# %%
# Настройка сплиттера текста
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=512,
    chunk_overlap=100,
    separators=['\n\n', '\n', '. ', ' ', ''],
    length_function=len
)

document_texts = stratified_data['fullText'].tolist()
document_metadata = stratified_data[['Name', 'City', 'description']].to_dict('records')

# Создание чанков
all_chunks = []
all_metadata = []

for text_index, current_text in enumerate(document_texts):
    if isinstance(current_text, str) and len(current_text) > 10:
        chunks = text_splitter.split_text(current_text)

        for text_chunk in chunks:
            all_chunks.append(text_chunk)
            all_metadata.append(document_metadata[text_index])

print(f'Создано {len(all_chunks)} чанков из {len(document_texts)} документов')

# Загрузка модели эмбеддингов
embedding_model = SentenceTransformer('intfloat/multilingual-e5-small')
embedding_model = embedding_model.to(device)
embedding_model.eval()
print('Модель эмбеддингов загружена')

# Создание эмбеддингов
chunk_embeddings = embedding_model.encode(
    all_chunks,
    normalize_embeddings=True,
    show_progress_bar=True,
    batch_size=32
)
print(f'Эмбеддинги созданы, форма: {chunk_embeddings.shape}')

faiss_index = faiss.IndexFlatIP(chunk_embeddings.shape[1])
faiss_index.add(chunk_embeddings.astype('float32'))
print(f'Векторная база данных создана, размерность: {faiss_index.d}')
# Out:
# Создано 100 чанков из 100 документов
# Модель эмбеддингов загружена
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Эмбеддинги созданы, форма: (100, 384)
# Векторная база данных создана, размерность: 384

# %%
def search_chunks_by_query(search_query, results_number=10):
    query_embedding = embedding_model.encode([search_query], normalize_embeddings=True)
    distance_scores, found_indices = faiss_index.search(query_embedding.astype('float32'), results_number)
    search_results = []

    for result_index, score_value in zip(found_indices[0], distance_scores[0]):
        search_results.append({
            'text': all_chunks[result_index],
            'metaData': all_metadata[result_index],
            'score': float(score_value)
        })

    return search_results

# %%
reranker_model = FlagReranker('BAAI/bge-reranker-large', use_fp16=True)
print('Модель переранжировщика загружена')
# Out:
# Модель переранжировщика загружена

# %%
# Отключаем прогресс-бары
os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'

# Временно перенаправляем потоки вывода
original_stdout = sys.stdout
original_stderr = sys.stderr
sys.stdout = open(os.devnull, 'w')
sys.stderr = open(os.devnull, 'w')

try:
    reader_model_name = 'google/flan-t5-base'
    reader_tokenizer = AutoTokenizer.from_pretrained(reader_model_name)
    reader_model = AutoModelForSeq2SeqLM.from_pretrained(
        reader_model_name,
        device_map='auto',
        torch_dtype=torch.float32
    )
    reader_pipeline = pipeline(
        'text2text-generation',
        model=reader_model,
        tokenizer=reader_tokenizer,
        max_new_tokens=200,
        do_sample=False
    )
finally:
    # Восстанавливаем вывод
    sys.stdout.close()
    sys.stderr.close()
    sys.stdout = original_stdout
    sys.stderr = original_stderr

print('Модель для генерации ответов загружена')
# Out:
# Device set to use cuda:0
# Модель для генерации ответов загружена

# %% [markdown]
# Выполните визуализацию эмбеддингов при помощи метода главных компонент (PCA) и Uniform Manifold Approximation and Projection (UMAP). Пожалуйста, выполните PCA независимо от pacmap.

# %%
# Берём строки с городами
has_city = stratified_data["City"].notna()
cities_data = stratified_data[has_city].copy()

# Если записей с городами достаточно, используем их все
sample_size = min(2000, len(cities_data))
sample_data = cities_data.sample(sample_size, random_state=42).copy()

# Создаём эмбеддинги
sample_embeddings = np.array(embedding_model.encode(
    sample_data['fullText'].fillna('').tolist(),
    normalize_embeddings=False,
    show_progress_bar=True
))

# Берём города
city_names = sample_data["City"].tolist()

# Нормализация
scaler = StandardScaler()
sample_embeddings_scaled = scaler.fit_transform(sample_embeddings)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(sample_embeddings_scaled)

explained_variance = pca.explained_variance_ratio_

# Визуализация
plt.figure(figsize=(14, 10))

known_cities = list(set(city_names))
colors = ['red', 'blue', 'green', 'orange', 'purple']

for index, city in enumerate(known_cities):
    mask = [item == city for item in city_names]

    if sum(mask) > 0:
        plt.scatter(
            pca_result[mask, 0],
            pca_result[mask, 1],
            label=f'{city} ({sum(mask)})',
            alpha=0.6,
            s=30,
            color=colors[index % len(colors)]
        )

plt.title('Визуализация эмбеддингов достопримечательностей', fontsize=14)
plt.xlabel(f'Первая главная компонента (объяснённая дисперсия: {explained_variance[0]:.2%})', fontsize=12)
plt.ylabel(f'Вторая главная компонента (объяснённая дисперсия: {explained_variance[1]:.2%})', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
sil_score_pca = silhouette_score(sample_embeddings_scaled, [known_cities.index(city) for city in city_names if city in known_cities[:len(colors)]])
print(f'Коэффициент силуэта: {sil_score_pca:.4f}')
# Out:
# Коэффициент силуэта: 0.0815

# %%
# Нормализация
scaler = MinMaxScaler()
sample_embeddings = scaler.fit_transform(sample_embeddings)

# Уменьшение размерности
umap_reducer = umap.UMAP(
    n_components=2,
    n_neighbors=15,
    min_dist=0.1,
    metric='euclidean',
    random_state=42
)
umap_result = umap_reducer.fit_transform(sample_embeddings)

# Визуализация
plt.figure(figsize=(14, 10))

known_cities = list(set(city_names))
colors = ['red', 'blue', 'green', 'orange', 'purple']

for index, city in enumerate(known_cities):
    mask = [item == city for item in city_names]

    if sum(mask) > 0:
        plt.scatter(
            umap_result[mask, 0],
            umap_result[mask, 1],
            label=f'{city} ({sum(mask)})',
            alpha=0.6,
            s=30,
            color=colors[index % len(colors)]
        )

plt.title('Визуализация эмбеддингов достопримечательностей', fontsize=14)
plt.xlabel('Горизонтальная компонента', fontsize=12)
plt.ylabel('Вертикальная компонента', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# НУЖНО РЕАЛИЗВАТЬ!!!

# %%
# from sklearn.decomposition import PCA
# import umap
# import matplotlib.pyplot as plt
# import numpy as np

# embeddings_matrix = np.array([embeddings.embed_query(doc.page_content) for doc in documents])

# pca = PCA(n_components=2)
# embeddings_pca = pca.fit_transform(embeddings_matrix)

# umap_reducer = umap.UMAP(n_components=2, random_state=42, n_neighbors=15, min_dist=0.1)
# embeddings_umap = umap_reducer.fit_transform(embeddings_matrix)

# fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# axes[0].scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], alpha=0.7, s=30)
# axes[0].set_title(f'PCA (explained variance: {pca.explained_variance_ratio_.sum():.2%})')
# axes[0].set_xlabel('PC1')
# axes[0].set_ylabel('PC2')

# scatter = axes[1].scatter(embeddings_umap[:, 0], embeddings_umap[:, 1],
#                           c=range(len(documents)), cmap='viridis', alpha=0.7, s=30)
# axes[1].set_title('UMAP projection')
# axes[1].set_xlabel('UMAP1')
# axes[1].set_ylabel('UMAP2')
# plt.colorbar(scatter, ax=axes[1], label='Document index')

# plt.tight_layout()
# plt.show()

# print(f"PCA explained variance ratio: {pca.explained_variance_ratio_}")

# %% [markdown]
# # RAGAS (3 балла)

# %% [markdown]
# RAGAS - это система, созданная для автоматической оценки эффективности модели RAG. Она представляет собой комплексный инструмент, способный оценить как качество извлечения информации, так и качество созданного текста. Это достигается благодаря использованию различных метрик, которые анализируют разные аспекты ответов, сгенерированных языковой моделью.

# %% [markdown]
# ## Метрики оценки в RAGAS

# %% [markdown]
# ### Faithfulness
# Оценивает, насколько ответы языковой модели верно передают информацию, содержащуюся в источниках данных. Это критически важно, чтобы гарантировать, что модель не искажает или не меняет информацию при её интерпретации.
#
# ---
#
# $
# Faithfulness = \frac{\text{|Number of claims that can be inferred from given context|}}{\text{|Total number of claims in the generated answer|}}
# $

# %% [markdown]
# ### Answer Relevancy
# Демонстрирует, насколько ответы соответствуют заданным вопросам. Это важный аспект, так как даже правильный ответ с технической точки зрения может быть ненужным, если он не отвечает на конкретный вопрос пользователя.
#
# ---
#
# $\text{answer relevancy} = \frac{1}{N} \sum_{i=1}^{N} cos(E_{g_i}, E_o)$
#
# $\text{answer relevancy} = \frac{1}{N} \sum_{i=1}^{N} \frac{E_{g_i} \cdot E_o}{\|E_{g_i}\|\|E_o\|}$
#
# Где:
#
# * $E_{g_i}$ - это эмбеддинг сгенерированного ответа $i$
#
# * $E_o$ - это эмбеддинг исходного вопроса.
#
# * $N$ - это количество сгенерированных вопросов, которое по умолчанию равно 3.

# %% [markdown]
# ### Context Recall и Context Precision
# Эти метрики измеряют эффективность модели в учете контекста вопроса для формирования ответа. "Context Recall" оценивает количество использованной информации из контекста в ответе, в то время как "Context Precision" оценивает точность и релевантность использования контекстной информации.
#
# ---
#
# * $ \text{context recall} = \frac{\text{|GT sentences that can be attributed to context|}}{\text{|Number of sentences in GT|}} $
# * $Context Precision@k = \frac{\sum \text{precision@k}}{\text{total number of relevant items in the top K results}}$
#   * $Precision@k = \frac{\text {true positives@k}}{\text{(true positives@k + false positives@k)}}$

# %% [markdown]
# ### Answer Semantic Similarity
# Оценивает степень семантической близости между ответом модели и эталонным ответом. Это позволяет определить, насколько естественно и точно модель способна воссоздавать человеческий язык.

# %% [markdown]
# ### Answer Correctness
# Оценка корректности ответа. Это последний шаг в проверке, чтобы убедиться, предоставляет ли модель точную и достоверную информацию в своем ответе.

# %% [markdown]
# В этом задании вам нужно реализовать метрику answer_relevancy в коде. Опционально за допбаллы можно реализовать другие метрики.

# %% [markdown]
# Для этого датасет нужно привести к виду, в котором будут следующие поля:
#
# ### 1. question
# - Смысл: Эта колонка содержит вопросы, на которые нужно найти ответы. В контексте задач QA, это основная информация, которую модель должна обработать для генерации ответа.
# - Пример: "Каковы преимущества RAG?"
#
# ### 2. ground_truths
# - Смысл: В этой колонке находятся правильные ответы на соответствующие вопросы. Это может использоваться для оценки производительности модели, так как позволяет сравнить сгенерированные ответы с эталонными.
# - Пример: "RAG улучшает качество генерации, используя внешние источники информации."
#
# ### 3. answer
# - Смысл: Эта колонка содержит ответы, которые генерирует модель на основе заданных вопросов. Это может быть результат работы модели, которую вы тестируете или обучаете.
# - Пример: "RAG позволяет моделям извлекать информацию из внешних источников, что улучшает их способность отвечать на сложные вопросы."
#
# ### 4. contexts
# - Смысл: Эта колонка предоставляет контекст или дополнительную информацию, которая может быть полезна для понимания вопроса или для формирования ответа. Это может быть текст, из которого был извлечен ответ, или другие релевантные документы.
# - Пример: "RAG (Retrieval-Augmented Generation) — это метод, который использует внешние базы данных для получения информации при генерации текста."

# %% [markdown]
# HINT: Поле question можно тоже сгенерировать. Например, можно попросить модель задать вопрос по описанию изображения.
#
# HINT: Для answer_relevancy нужны не все поля
#
# HINT: Инференс такого эксперимента может быть долгим. План минимум: возьмите 100 случайных сэмплов.

# %%
def rag_query(question, top_k_retrieve=10, top_k_final=3):
    if not isinstance(question, str) or len(question.strip()) == 0:
        return 'Информация не найдена', []

    # Поиск релевантных чанков
    retrieved = search_chunks_by_query(question, results_number=top_k_retrieve)
    retrieved_texts = [item['text'] for item in retrieved]
    retrieved_metadata = [item['metaData'] for item in retrieved]

    # Ранжирование через FlagReranker
    pairs = [[question, text] for text in retrieved_texts]
    scores = reranker_model.compute_score(pairs)

    # Сортировка по убыванию релевантности
    scored = list(zip(retrieved_texts, retrieved_metadata, scores))
    scored.sort(key=lambda x: x[2], reverse=True)

    # Берём отсортированные данные
    final_results = scored[:top_k_final]
    final_metadata = [item[1] for item in final_results]
    final_texts = [item[0] for item in final_results]

    # Возвращаем первый найденный контекст как ответ
    if final_metadata:
        item = final_metadata[0]
        # Безопасное получение полей с проверкой на NaN
        name = item.get("Name", '')
        city = item.get("City", '')
        description = item.get('description', '')

        # Проверка на NaN и преобразование в строку
        if pd.isna(name):
            name = ''

        if pd.isna(city):
            city = ''

        if pd.isna(description):
            description = ''

        # Преобразуем в строку и обрезаем
        name = str(name)
        city = str(city)
        description = str(description)[:200]

        answer = f'{name}. {city}. {description}'
    else:
        answer = 'Информация не найдена'

    return answer, final_texts

# %%
def data_preprocess(data, sample_size=50):
    sampled_data = data.sample(min(sample_size, len(data)), random_state=42)
    evaluation_data = []

    for _, row in tqdm(sampled_data.iterrows(), total=len(sampled_data), desc='Обработка'):
        try:
            if pd.isna(row["Name"]) or pd.isna(row["City"]):
                continue

            city_name = row["City"]
            question = f'Опишите {row["Name"]} в городе {city_name}'
            answer, contexts = rag_query(question)

            # Проверка, что контексты не пустые
            if not contexts:
                print(f'Нет контекстов для {row["Name"]}')

                continue

            evaluation_data.append({
                'question': question,
                'answer': answer,
                'contexts': contexts,
                'groundTruths': row['description']
            })
        except Exception as error:
            print(f'Ошибка при обработке {row["Name"]}: {error}')

            continue

    evaluation_data = pd.DataFrame(evaluation_data)
    print(f'Подготовлено {len(evaluation_data)} примеров для оценки')

    return evaluation_data

# %%
def answer_relevancy(question, answer, embedding_model, generated_questions=3):
    if not isinstance(question, str) or not isinstance(answer, str):
        return {'answerRelevancy': 0.0, 'directSimilarity': 0.0, 'generatedSimilarity': 0.0, 'generatedQuestions': 0}

    if len(question.strip()) == 0 or len(answer.strip()) == 0:
        return {'answerRelevancy': 0.0, 'directSimilarity': 0.0, 'generatedSimilarity': 0.0, 'generatedQuestions': 0}

    # Эмбеддинг исходного вопроса
    question_embedding = embedding_model.encode([question], normalize_embeddings=True)[0]

    # Разбиваем ответ на предложения для генерации обратных вопросов
    answer_sentences = answer.split('. ')
    generated_questions_list = []

    # Генерируем обратные вопросы на основе ключевых слов из ответа
    for sentence in answer_sentences[:generated_questions]:
        if len(sentence) > 20:  # Берем только достаточно длинные предложения
            # Извлекаем ключевые слова (первые 5 слов предложения)
            key_words = sentence.split()[:5]

            if key_words:
                generated_question = f'Что такое {" ".join(key_words)}?'
                generated_questions_list.append(generated_question)

    # Если не удалось сгенерировать вопросы, используем исходный вопрос
    if not generated_questions_list:
        generated_questions_list = [question]

    # Вычисляем косинусное сходство между исходным вопросом и сгенерированными вопросами
    similarity_scores = []

    for generated_question in generated_questions_list:
        generated_question_embedding = embedding_model.encode([generated_question], normalize_embeddings=True)[0]
        similarity_score = float(np.dot(question_embedding, generated_question_embedding))
        similarity_scores.append(similarity_score)

    # Вычисляем прямое сходство между вопросом и ответом
    answer_embedding = embedding_model.encode([answer], normalize_embeddings=True)[0]
    direct_similarity_score = float(np.dot(question_embedding, answer_embedding))

    # Итоговый score (среднее арифметическое прямого и обратного сходства)
    final_relevancy_score = (direct_similarity_score + np.mean(similarity_scores)) / 2

    return {
        'answerRelevancy': final_relevancy_score,
        'directSimilarity': direct_similarity_score,
        'generatedSimilarity': np.mean(similarity_scores),
        'generatedQuestions': len(generated_questions_list)
    }

# %%
# Создание датасета для оценки
sample_size = min(50, len(stratified_data))
evaluation_dataset = data_preprocess(stratified_data, sample_size=sample_size)

# Вычисление релевантности ответа для всех примеров
relevancy_scores = []

for index, row in evaluation_dataset.iterrows():
    relevancy_result = answer_relevancy(
        row['question'],
        row['answer'],
        embedding_model
    )
    relevancy_scores.append(relevancy_result['answerRelevancy'])

    if index % 10 == 0:
        print(f'Обработано {index} из {len(evaluation_dataset)} примеров')

print(f'Релевантность ответа: {np.mean(relevancy_scores):.4f}')
print(f'Стандартное отклонение: {np.std(relevancy_scores):.4f}')
# Out:
# Обработка:   0%|          | 0/50 [00:00<?, ?it/s]
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Подготовлено 50 примеров для оценки
# Обработано 0 из 50 примеров
# Обработано 10 из 50 примеров
# Обработано 20 из 50 примеров
# Обработано 30 из 50 примеров
# Обработано 40 из 50 примеров
# Релевантность ответа: 0.9319
# Стандартное отклонение: 0.0260

# %% [markdown]
# # Протестируйте ваш RAG (3 балла)

# %%
testing_questions = [
    'Какие музеи есть в Екатеринбурге?',
    'Где находится Дом-музей Бажова?',
    'Что можно посмотреть в Харитоновском саду?',
    'Где находится Свято-Троицкий кафедральный собор?',
    'Какие театры есть в Екатеринбурге?',
    'Где находится Суворовское училище?',
    'Что представляет собой Художественный музей Эрнста Неизвестного?',
    'Где находится памятник Серго Орджоникидзе?',
    'Какие исторические здания есть в Екатеринбурге?',
    'Где находится Дом обороны?',
    'Какие памятники архитектуры есть в центре Екатеринбурга?',
    'Где находится Театр кукол в Екатеринбурге?',
    'Что можно увидеть в Литературной жизни Урала XX века?',
    'Где находится Храм Вознесения Господня?',
    'Какие достопримечательности есть в районе Плотинки?',
    'Где находится Дом-музей Мамина-Сибиряка?',
    'Что находится на площади 1905 года?',
    'Где расположен памятник Татищеву и де Геннину?',
    'Какие православные храмы есть в Екатеринбурге?',
    'Где находится Уральский геологический музей?',
    'Что находится в Екатеринбургском музее изобразительных искусств?',
    'Где находится Царский мост?',
    'Какие памятники есть в Екатеринбурге?',
    'Где находится Дом Севастьянова?',
    'Что можно увидеть в Уральской государственной консерватории?',
    'Где находится Ново-Тихвинский монастырь?',
    'Какие достопримечательности есть во Владимире?',
    'Где находятся Золотые ворота?',
    'Что такое Белокаменные памятники Владимира и Суздаля?',
    'Где находится Дмитриевский собор?',
    'Какие церкви есть во Владимире?',
    'Где находится Богородице-Рождественский монастырь?',
    'Что можно увидеть в Троицкой церкви Владимира?',
    'Где находится Собор Успения Пресвятой Богородицы?',
    'Какие музеи есть в Ярославле?',
    'Где находится Демидовский столп?',
    'Что можно посмотреть в Ярославском музее-заповеднике?',
    'Где находится Церковь Ильи Пророка?',
    'Какие театры есть в Ярославле?',
    'Где находится Спасо-Преображенский монастырь?',
    'Какие достопримечательности есть в Нижнем Новгороде?',
    'Где находится Нижегородский кремль?',
    'Что представляет собой Чкаловская лестница?',
    'Где находится Церковь Рождества Иоанна Предтечи?',
    'Какие музеи есть в Нижнем Новгороде?',
    'Где находится памятник Минину и Пожарскому?',
    'Что можно увидеть в Нижегородском речном училище?',
    'Где находится Благовещенский монастырь?',
    'Какие храмы есть в Нижнем Новгороде?',
    'Где находится Крестовоздвиженский собор?'
]

scores = []

print('\n' + '=' * 100)
print('Тестирование RAG системы')
print('=' * 100)

for question in testing_questions:
    print(f'Вопрос: {question}')
    answer, contexts = rag_query(question)
    print(f'Ответ: {answer[:500]}')
    print(f'Использовано контекстов: {len(contexts)}')
    print('-' * 50)
# Out:
# ====================================================================================================
# Тестирование RAG системы
# ====================================================================================================
# Вопрос: Какие музеи есть в Екатеринбурге?
# Ответ: Музей кукол и детской книги «Страна чудес». Екатеринбург. Музей кукол и детской книги «Страна чудес»
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Дом-музей Бажова?
# Ответ: Усадьба Е. И. Богоявленской. Нижний Новгород. Усадьба Е. И. Богоявленской
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно посмотреть в Харитоновском саду?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Свято-Троицкий кафедральный собор?
# Ответ: Старообрядческий храм Иоанна Златоуста в Коровниках. Ярославль. Православный храм в Ярославле
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие театры есть в Екатеринбурге?
# Ответ: Музей кукол и детской книги «Страна чудес». Екатеринбург. Музей кукол и детской книги «Страна чудес»
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Суворовское училище?
# Ответ: Уральская государственная консерватория. Екатеринбург. высшее учебное заведение в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что представляет собой Художественный музей Эрнста Неизвестного?
# Ответ: Музей древнерусского искусства. Ярославль. Митрополичьи палаты (Ярославль)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится памятник Серго Орджоникидзе?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие исторические здания есть в Екатеринбурге?
# Ответ: Ново-Тихвинский монастырь. Екатеринбург. Ново-Тихвинский монастырь
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Дом обороны?
# Ответ: №32 Дом обороны. Екатеринбург. здание в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие памятники архитектуры есть в центре Екатеринбурга?
# Ответ: Александро-Невский собор. Екатеринбург. православный собор в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Театр кукол в Екатеринбурге?
# Ответ: Музей кукол и детской книги «Страна чудес». Екатеринбург. Музей кукол и детской книги «Страна чудес»
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно увидеть в Литературной жизни Урала XX века?
# Ответ: Музей кукол и детской книги «Страна чудес». Екатеринбург. Музей кукол и детской книги «Страна чудес»
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Храм Вознесения Господня?
# Ответ: Владимирская митрополия. Владимир. Владимирский кремль
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие достопримечательности есть в районе Плотинки?
# Ответ: Парк имени Кулибина. Нижний Новгород. Парк Кулибина
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Дом-музей Мамина-Сибиряка?
# Ответ: Н. И. Кузнецову. Екатеринбург. Памятник в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что находится на площади 1905 года?
# Ответ: Дмитриевская башня. Нижний Новгород. проездная башня Нижегородского кремля, один из символов Нижнего Новгорода
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где расположен памятник Татищеву и де Геннину?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие православные храмы есть в Екатеринбурге?
# Ответ: Свято-Троицкий Кафедральный собор. Екатеринбург. Троицкий собор (Екатеринбург)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Уральский геологический музей?
# Ответ: Комсомолу Урала. Екатеринбург. памятник в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что находится в Екатеринбургском музее изобразительных искусств?
# Ответ: Памятник Я.М. Свердлову. Екатеринбург. памятник в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Царский мост?
# Ответ: Дмитриевская башня. Нижний Новгород. проездная башня Нижегородского кремля, один из символов Нижнего Новгорода
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие памятники есть в Екатеринбурге?
# Ответ: Александро-Невский собор. Екатеринбург. православный собор в Екатеринбурге
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Дом Севастьянова?
# Ответ: Усадьба Добролюбовых. Нижний Новгород. единственный в мире музей литературного критика и писателя Николая Александровича Добролюбова, расположенный в Нижнем Новгороде.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно увидеть в Уральской государственной консерватории?
# Ответ: Музей древнерусского искусства. Ярославль. Митрополичьи палаты (Ярославль)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Ново-Тихвинский монастырь?
# Ответ: Ново-Тихвинский монастырь. Екатеринбург. Ново-Тихвинский монастырь
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие достопримечательности есть во Владимире?
# Ответ: Парк имени Кулибина. Нижний Новгород. Парк Кулибина
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находятся Золотые ворота?
# Ответ: Усадьба Добролюбовых. Нижний Новгород. единственный в мире музей литературного критика и писателя Николая Александровича Добролюбова, расположенный в Нижнем Новгороде.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что такое Белокаменные памятники Владимира и Суздаля?
# Ответ: Памятник 1000-летию Ярославля. Ярославль. Памятник в Ярославле
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Дмитриевский собор?
# Ответ: Cerkiew św. Dymitra Sołuńskiego w Jarosławiu. Ярославль. Церковь великомученика Димитрия Солунского (Смоленская) (Ярославль)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие церкви есть во Владимире?
# Ответ: Троицкая церковь. Владимир. Троицкая церковь
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Богородице-Рождественский монастырь?
# Ответ: Старообрядческий храм Иоанна Златоуста в Коровниках. Ярославль. Православный храм в Ярославле
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно увидеть в Троицкой церкви Владимира?
# Ответ: Собор Архангела Михаила. Нижний Новгород. православный храм
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Собор Успения Пресвятой Богородицы?
# Ответ: Церковь Николая Надеина. Ярославль. Православный храм в Ярославле
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие музеи есть в Ярославле?
# Ответ: Музей истории города Ярославля. Ярославль. Музей истории города Ярославля
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Демидовский столп?
# Ответ: Дмитриевская башня. Нижний Новгород. проездная башня Нижегородского кремля, один из символов Нижнего Новгорода
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно посмотреть в Ярославском музее-заповеднике?
# Ответ: Музей древнерусского искусства. Ярославль. Митрополичьи палаты (Ярославль)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Церковь Ильи Пророка?
# Ответ: Собор Александра Невского. Нижний Новгород. православный собор в Нижнем Новгороде
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие театры есть в Ярославле?
# Ответ: Ярославский камерный театр. Ярославль. Ярославский камерный театр
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Спасо-Преображенский монастырь?
# Ответ: Спасский староярмарочный кафедральный собор. Нижний Новгород. Собор на Нижегородской ярмарке
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие достопримечательности есть в Нижнем Новгороде?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Нижегородский кремль?
# Ответ: Собор Архангела Михаила. Нижний Новгород. православный храм
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что представляет собой Чкаловская лестница?
# Ответ: Борисоглебская башня. Нижний Новгород. круглая башня Нижегородского кремля
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Церковь Рождества Иоанна Предтечи?
# Ответ: Cerkiew Narodzenia Pańskiego w Jarosławiu. Ярославль. Православный храм в Ярославле
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие музеи есть в Нижнем Новгороде?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится памятник Минину и Пожарскому?
# Ответ: Нижегородский государственный художественный музей. Нижний Новгород. один из старейших музеев России, крупнейший музей изобразительного искусства в Нижегородской области.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Что можно увидеть в Нижегородском речном училище?
# Ответ: Усадьба Добролюбовых. Нижний Новгород. единственный в мире музей литературного критика и писателя Николая Александровича Добролюбова, расположенный в Нижнем Новгороде.
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Благовещенский монастырь?
# Ответ: Борисоглебская башня. Нижний Новгород. круглая башня Нижегородского кремля
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Какие храмы есть в Нижнем Новгороде?
# Ответ: Спасо-преображенская церковь. Нижний Новгород. Спасо-Преображенская церковь (Карповка)
# Использовано контекстов: 3
# --------------------------------------------------
# Вопрос: Где находится Крестовоздвиженский собор?
# Ответ: Церковь Воскресения Христова. Нижний Новгород. Воскресенская церковь (Нижний Новгород)
# Использовано контекстов: 3
# --------------------------------------------------

# %% [markdown]
# # Дополнительная часть (+3 балла)

# %% [markdown]
# Реализуйте одну из метрик retrieval-части на выбор.
#
# Для того, чтобы понять model as a judge подход из RAGAS, советуем посетить [этот кукбук](https://huggingface.co/learn/cookbook/en/rag_evaluation)

# %%
# Метрика точности контекста
def context_precision(question, contexts, embedding_model, threshold=0.7):
    question_embedding = embedding_model.encode([question], normalize_embeddings=True)[0]
    relevant_count = 0
    precision_sum = 0

    for index, context in enumerate(contexts, 1):
        context_embedding = embedding_model.encode([context], normalize_embeddings=True)[0]
        similarity = float(np.dot(question_embedding, context_embedding))

        if similarity > threshold:
            relevant_count += 1

        precision_sum += relevant_count / index

    return precision_sum / len(contexts) if contexts else 0.0

# Вычисление точности контекста для всех примеров
precision_scores = []

for _, row in evaluation_dataset.iterrows():
    # Проверка на валидность данных
    if not isinstance(row['question'], str) or not isinstance(row['contexts'], list):
        continue

    if len(row['contexts']) == 0:
        continue

    score = context_precision(row['question'], row['contexts'], embedding_model)
    precision_scores.append(score)

print(f'Точность контекста: {np.mean(precision_scores):.4f}')
print(f'Стандартное отклонение: {np.std(precision_scores):.4f}')
print(f'Минимальное значение: {np.min(precision_scores):.4f}')
print(f'Максимальное значение: {np.max(precision_scores):.4f}')
# Out:
# Точность контекста: 1.0000
# Стандартное отклонение: 0.0000
# Минимальное значение: 1.0000
# Максимальное значение: 1.0000

# %%
# Метрика полнота контекста
def context_recall(ground_truth, contexts, embedding_model, threshold=0.5):
    if ground_truth is None or pd.isna(ground_truth):
        return 0.0

    if not isinstance(ground_truth, str):
        return 0.0

    if not contexts:
        return 0.0

    ground_truth_embedding = embedding_model.encode([ground_truth], normalize_embeddings=True)[0]
    context_embeddings = embedding_model.encode(contexts, normalize_embeddings=True)

    similarities = [float(np.dot(ground_truth_embedding, context_embedding)) for context_embedding in context_embeddings]

    relevant = sum(1 for similarity in similarities if similarity > threshold)

    return relevant / len(contexts) if contexts else 0.0

# Вычисление полнота контекста для всех примеров
recall_scores = []

for _, row in evaluation_dataset.iterrows():
    if pd.isna(row['groundTruths']) or not isinstance(row['groundTruths'], str):
        continue

    score = context_recall(row['groundTruths'], row['contexts'], embedding_model)
    recall_scores.append(score)

print(f'Полнота контекста: {np.mean(recall_scores):.4f}')
print(f'Стандартное отклонение: {np.std(recall_scores):.4f}')
print(f'Минимальное значение: {np.min(recall_scores):.4f}')
print(f'Максимальное значение: {np.max(recall_scores):.4f}')
# Out:
# Полнота контекста: 1.0000
# Стандартное отклонение: 0.0000
# Минимальное значение: 1.0000
# Максимальное значение: 1.0000
