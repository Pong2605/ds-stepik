# %%
# Вариант 1: Без установки зависимостей (самый безопасный)

# !pip install pyALE --no-deps -q

# %%
# Вариант 2: Без обновления существующих библиотек

# !pip install pyALE --upgrade-strategy only-if-needed -q

# %%
# Вариант 3: Установка конкретной версии (если нужна)

# !pip install pyALE==1.4.1 --no-deps -q
